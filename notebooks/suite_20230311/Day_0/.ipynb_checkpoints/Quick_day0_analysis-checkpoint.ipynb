# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import numpy as np
import torch
import pickle
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
import bmi_idap
from bnpm import torch_helpers, ca2p_preprocessing, file_helpers

# %%
decoder_definition_path = r"D:\RH_local\data\BMI_cage_g8Test\mouse_g8t\20230314\analysis_data\day0_analysis\decoder_definition.pkl"

# %%
with open(decoder_definition_path, 'rb') as handle:
    decoder_definition = pickle.load(handle)

# %%
decoder_definition
# Out:
# {'results': {'general': {'datetime': '2023-03-15 00:06:21.354845',
#    'cwd': '/media/rich/Home_Linux_partition/github_repos/BMI_IDAP/notebooks/suite_20230311/Day_0'},
#   'device': 'cuda:0',
#   'data': {'data': 108000,
#    'n_rois': 2452,
#    'Fs': 30.0,
#    'frame_height': 512,
#    'frame_width': 1024,
#    'spatialFootprints': <2452x524288 sparse matrix of type '<class 'numpy.float32'>'
#    	with 249524 stored elements in Compressed Sparse Row format>,
#    'iscell': array([ True,  True,  True, ..., False, False,  True])},
#   'idx_time_bad': array([], dtype=int64),
#   'preorthogonalization': {'signals': array([[-2.5834443e-02, -2.5817139e-02, -2.5799835e-02, ...,
#            -5.9836566e-02, -5.9855055e-02, -5.9873544e-02],
#           [-8.8288088e-04, -6.6723971e-04, -4.5160030e-04, ...,
#             1.0623486e-04, -3.8832205e-04, -8.8288949e-04],
#           [-6.5628687e-06, -6.1427592e-05, -1.0711063e-04, ...,
# ...

# %%
decoder_definition.keys()
# Out:
# dict_keys(['results', 'params'])

# %%
results = decoder_definition['results']
params = decoder_definition['params']

# %% [markdown]
# # Day 0 dFoF

# %%
## == IMPORT DATA ==
F, Fneu, iscell_s2p, ops, spks_s2p, stat = ca2p_preprocessing.import_s2p(r'D:\RH_local\data\BMI_cage_g8Test\mouse_g8t\20230314\analysis_data\suite2p\plane0')
n_frames, n_rois = F.shape[1], F.shape[0]
Fs = ops['fs']

# %%
iscell = results['data']['iscell']
F_toUse = F[iscell]
Fneu_toUse = Fneu[iscell]

# %%
iscell
# Out:
# array([ True,  True,  True, ..., False, False,  True])

# %%
params['dFoF']
# Out:
# {'channelOffset_correction': 0,
#  'percentile_baseline': 30,
#  'neuropil_fraction': 0.7,
#  'win_rolling_percentile': 18000}

# %%
# dFoF with reduced percentile for baseline

dFoF, dF, F_neuSub, F_baseline = ca2p_preprocessing.make_dFoF(
    F=F_toUse,
    Fneu=Fneu_toUse,
    neuropil_fraction=params['dFoF']['neuropil_fraction'],
    percentile_baseline=params['dFoF']['percentile_baseline'],
    rolling_percentile_window=int(params['dFoF']['win_rolling_percentile']),
    channelOffset_correction=params['dFoF']['channelOffset_correction'],
    multicore_pref=True,
    verbose=True
)
# # Threshold for nonnegativity
# dFoF_z = dFoF / np.std(dFoF,axis=1,keepdims=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:17<00:00,  1.11it/s]
# Calculated dFoF. Total elapsed time: 19.91 seconds

# %%
np.sum(dFoF > 30)
# Out:
# 0

# %% [raw]
# params = {}
# params['simulation'] = {}
#
# params['simulation']['power'] = 1.5
# params['simulation']['idx_factor'] = 0
# params['simulation']['idx_avg'] = -1
# params['simulation']['thresh_reward'] = 2.0
# params['simulation']['thresh_quiescence_cursor'] = 0.2 * params['simulation']['thresh_reward']
# params['simulation']['duration_quiescence_hold'] = 3
# params['simulation']['duration_threshold_hold'] = 3
# params['simulation']['win_smooth_cursor'] = 3

# %%
device = torch_helpers.set_device(use_GPU=True)
# Out:
# devices available: [_CudaDeviceProperties(name='NVIDIA GeForce RTX 2080 Ti', major=7, minor=5, total_memory=11264MB, multi_processor_count=68)]
# Using device: 'cuda:0': _CudaDeviceProperties(name='NVIDIA GeForce RTX 2080 Ti', major=7, minor=5, total_memory=11264MB, multi_processor_count=68)

# %%
params['simulation']
# Out:
# {'power': 1.5,
#  'idx_factor': 0,
#  'idx_avg': -1,
#  'thresh_reward': 2.8,
#  'thresh_quiescence_cursor': 0.5599999999999999,
#  'duration_quiescence_hold': 3,
#  'duration_threshold_hold': 3,
#  'win_smooth_cursor': 3,
#  'ptile_quiescence_avgVec': 0.8,
#  'thresh_quiescence_avgVec': tensor(0.9131, device='cuda:0')}

# %%
results['factors']['factors_final'].shape
# Out:
# (7, 1017)

# %%
# Remove avgVec from online decoder.
results['factors']['factors_final'] = results['factors']['factors_final'][:-1]

# %%
params['simulation']['power'] = 1.5

# %%
decoder = bmi_idap.decoder.Decoder_angle_magnitude(
    F=results['factors']['factors_final'].T,
    device=device,
    power=params['simulation']['power'],
)

D, CS, M = decoder(dFoF)

# %%
params['simulation']['idx_factor'] = 0

params['simulation']['thresh_reward'] = 3.0
params['simulation']['thresh_quiescence_cursorDecoder'] = 0.2 * params['simulation']['thresh_reward']

# Params with avgVec in decoder space.
params['simulation']['thresh_quiescence_cursorMag'] = 0.3
params['simulation']['thresh_quiescence_cursorMag'] = max([torch.quantile(M[params['simulation']['idx_factor']], q=params['simulation']['thresh_quiescence_cursorMag']).item(), 0])

# %%
params['simulation']['thresh_quiescence_cursorMag']

# %%
params['simulation']

# %%
num_rewards, sm = bmi_idap.decoder.simple_cursor_simulation(
    D.T, 
    CS.T, 
    M.T,
    idx_cursor=params['simulation']['idx_factor'], 
    idx_avg=params['simulation']['idx_avg'], 
    thresh_reward=params['simulation']['thresh_reward'], 
    thresh_quiescence_cursorMag=params['simulation']['thresh_quiescence_cursorMag'], 
    thresh_quiescence_cursorDecoder=params['simulation']['thresh_quiescence_cursorDecoder'], 
    duration_quiescence_hold=params['simulation']['duration_quiescence_hold'],
    duration_threshold_hold=params['simulation']['duration_threshold_hold'],
    win_smooth_cursor=1,
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 108000/108000 [00:26<00:00, 4086.50it/s]

# %%
num_rewards
# Out:
# 67

# %%
results['simulation']['num_rewards'] = num_rewards
results['simulation']['rewards_per_min'] = num_rewards / 60

# %%
# %matplotlib notebook
plt.figure(figsize=(20,5))
plt.plot(sm['cursor'])
plt.plot(sm['timeSeries_avgVec'], alpha=0.3)
plt.plot(sm['rewards']*0.5, linewidth=5)
plt.plot(sm['CS_quiescence']*0.3, alpha=0.6)
plt.plot(sm['CE_trial']*0.2)
plt.title('simulated experiment')
plt.xlabel('time (frames)');
# Out:
# <img src="data:image/png;base64,..." width="1999.999970197678">

# %%
# %matplotlib notebook
plt.figure(figsize=(20,10))
plt.plot(np.arange(D.shape[1])/Fs, (D.cpu() + torch.arange(D.shape[0])[:,None]*D.std(1).mean().cpu()*7).T)
plt.xlabel('time (s)');
# Out:
# <img src="data:image/png;base64,..." width="1999.999970197678">

# %%
plt.figure(figsize=(20,5))
plt.plot(CS.T.cpu());
plt.xlabel('time (frames)')
plt.ylabel('Cosine Similarity of factors + avgVec');
# Out:
# <img src="data:image/png;base64,..." width="1999.999970197678">

# %%
# %matplotlib notebook
plt.figure()
plt.imshow(np.corrcoef(D.cpu()), vmin=-1, vmax=1, cmap='bwr');
plt.title('correlation of decoder signals (D + avgVec) + avgVec');
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# %matplotlib notebook
plt.figure()
plt.imshow(np.corrcoef(D.cpu()), vmin=-1, vmax=1, cmap='bwr');
plt.title('correlation of decoder signals (D + avgVec) + avgVec');
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
results['simulation']
# Out:
# {'idx_factor': 0,
#  'D': tensor([[-3.2715e-02, -3.7969e-02, -3.3527e-02,  ..., -4.9336e-07,
#           -4.7967e-04,  8.9705e-04],
#          [-7.0403e-04, -1.2719e-03, -1.2814e-03,  ...,  4.0501e-02,
#            7.8818e-02,  4.7833e-02],
#          [ 1.9777e-02,  2.1805e-02,  4.5743e-07,  ...,  6.3648e-04,
#            2.4254e-02,  2.4997e-02],
#          ...,
#          [ 5.9093e-01,  2.7698e-01,  2.2358e-01,  ..., -2.7182e-01,
#           -4.2126e-01, -2.6054e-01],
#          [-3.5030e-02,  3.2469e-02,  7.9104e-03,  ..., -4.2380e-01,
#           -1.9143e-02, -1.9134e-01],
#          [ 1.4848e+00,  2.3028e+00,  2.7461e+00,  ...,  3.3654e-01,
#            5.5324e-01,  5.6411e-01]], device='cuda:0'),
#  'CS': tensor([[-0.1713, -0.1709, -0.1580,  ..., -0.0025, -0.0401,  0.0506],
#          [-0.0369, -0.0439, -0.0428,  ...,  0.2351,  0.3089,  0.2484],
#          [ 0.1401,  0.1369,  0.0018,  ...,  0.0447,  0.1928,  0.1916],
#          ...,
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(np.arange(results['simulation']['D'].shape[1])/Fs, (results['simulation']['D'].cpu() + torch.arange(results['simulation']['D'].shape[0])[:,None]*results['simulation']['D'].std(1).mean().cpu()*7).T)
plt.xlabel('time (s)');
# Out:
# <img src="data:image/png;base64,..." width="1999.999970197678">

# %%
plt.figure(figsize=(20,10))
plt.plot(np.arange(M.shape[1])/Fs, (M.cpu() + torch.arange(M.shape[0])[:,None]*M.std(1).mean().cpu()*7).T)
plt.xlabel('time (s)');
# Out:
# <img src="data:image/png;base64,..." width="1999.999970197678">

# %% [markdown]
# # Save brief simulation results

# %%
decoder_definition['params']['simulation']
# Out:
# {'power': 1.5,
#  'idx_factor': 0,
#  'idx_avg': -1,
#  'thresh_reward': 3.0,
#  'thresh_quiescence_cursor': 0.5599999999999999,
#  'duration_quiescence_hold': 3,
#  'duration_threshold_hold': 3,
#  'win_smooth_cursor': 3,
#  'ptile_quiescence_avgVec': 0.8,
#  'thresh_quiescence_avgVec': tensor(0.9131, device='cuda:0'),
#  'thresh_quiescence_cursorDecoder': 0.6000000000000001,
#  'thresh_quiescence_cursorMag': 0}

# %%
decoder_definition['results']['simulation']
# Out:
# {'idx_factor': 0,
#  'D': tensor([[-3.2715e-02, -3.7969e-02, -3.3527e-02,  ..., -4.9336e-07,
#           -4.7967e-04,  8.9705e-04],
#          [-7.0403e-04, -1.2719e-03, -1.2814e-03,  ...,  4.0501e-02,
#            7.8818e-02,  4.7833e-02],
#          [ 1.9777e-02,  2.1805e-02,  4.5743e-07,  ...,  6.3648e-04,
#            2.4254e-02,  2.4997e-02],
#          ...,
#          [ 5.9093e-01,  2.7698e-01,  2.2358e-01,  ..., -2.7182e-01,
#           -4.2126e-01, -2.6054e-01],
#          [-3.5030e-02,  3.2469e-02,  7.9104e-03,  ..., -4.2380e-01,
#           -1.9143e-02, -1.9134e-01],
#          [ 1.4848e+00,  2.3028e+00,  2.7461e+00,  ...,  3.3654e-01,
#            5.5324e-01,  5.6411e-01]], device='cuda:0'),
#  'CS': tensor([[-0.1713, -0.1709, -0.1580,  ..., -0.0025, -0.0401,  0.0506],
#          [-0.0369, -0.0439, -0.0428,  ...,  0.2351,  0.3089,  0.2484],
#          [ 0.1401,  0.1369,  0.0018,  ...,  0.0447,  0.1928,  0.1916],
#          ...,
# ...

# %%
with open('D:/RH_local/data/BMI_cage_g8Test/mouse_g8t/20230326/analysis_data/decoder_definition_usedinExp.pkl', 'wb') as handle:
    pickle.dump(decoder_definition, handle)

# %% [markdown]
# # dFoF Day N

# %%
import scipy.io

# %%
dayN_dFoF = scipy.io.loadmat('D:/RH_local/data/BMI_cage_g8Test/mouse_g8t/20230325/analysis_data/logger_dFoFROIs.mat')['logger_dFoFROIs'].T

# %%
dayN_dFoF = np.nan_to_num(dayN_dFoF)

# %%
plt.figure()
plt.plot(dayN_dFoF[150])

# %%
dFoF.shape
# Out:
# (1017, 108000)

# %%
dayN_dFoF.shape
# Out:
# (1017, 108000)

# %%
params['simulation']
# Out:
# {'power': 1.5,
#  'idx_factor': 0,
#  'idx_avg': -1,
#  'thresh_reward': 3.0,
#  'thresh_quiescence_cursor': 0.5599999999999999,
#  'duration_quiescence_hold': 3,
#  'duration_threshold_hold': 3,
#  'win_smooth_cursor': 3,
#  'ptile_quiescence_avgVec': 0.8,
#  'thresh_quiescence_avgVec': tensor(0.9131, device='cuda:0'),
#  'thresh_quiescence_cursorDecoder': 0.6000000000000001,
#  'thresh_quiescence_cursorMag': 0.3}

# %%
params['simulation']['idx_factor'] = 0

# %%
params['simulation']['idx_factor']
# Out:
# 0

# %%
params['simulation']['power'] = 1.5

# %%
params['simulation']['thresh_reward'] = 1.5
params['simulation']['thresh_quiescence_cursorDecoder'] = 0.2 * params['simulation']['thresh_reward']

# %%
decoder_dayN = bmi_idap.decoder.Decoder_angle_magnitude(
    F=results['factors']['factors_final'].T,
    device=device,
    power=params['simulation']['power'],
)

D_dayN, CS_dayN, M_dayN = decoder_dayN(dayN_dFoF)

# %%
D_dayN
# Out:
# tensor([[        nan, -7.1716e-02, -1.1895e-02,  ...,         nan,
#                  nan,         nan],
#         [        nan,  3.7876e-03, -6.9289e-02,  ...,         nan,
#                  nan,         nan],
#         [        nan, -6.2215e-03,  5.3531e-02,  ...,         nan,
#                  nan,         nan],
#         [        nan,  3.0674e-03, -1.5298e-01,  ...,         nan,
#                  nan,         nan],
#         [        nan,  6.6085e-04,  5.2894e-08,  ...,         nan,
#                  nan,         nan],
#         [        nan,  1.4361e-01,  1.3590e-02,  ...,         nan,
#                  nan,         nan]], device='cuda:0')

# %%
plt.figure()
plt.plot(D_dayN.cpu()[0])

# %%
CS_dayN
# Out:
# tensor([[    nan, -0.5695, -0.2407,  ...,     nan,     nan,     nan],
#         [    nan,  0.1756, -0.4871,  ...,     nan,     nan,     nan],
#         [    nan, -0.2142,  0.4394,  ...,     nan,     nan,     nan],
#         [    nan,  0.1614, -0.6687,  ...,     nan,     nan,     nan],
#         [    nan,  0.0874,  0.0017,  ...,     nan,     nan,     nan],
#         [    nan,  0.7518,  0.2539,  ...,     nan,     nan,     nan]],
#        device='cuda:0')

# %%
plt.figure()
plt.plot(CS_dayN.cpu()[0])

# %%
# Params with avgVec in decoder space.
params['simulation']['thresh_quiescence_cursorMag'] = 0.3
params['simulation']['thresh_quiescence_cursorMag'] = max([torch.quantile(M_dayN[params['simulation']['idx_factor']], q=params['simulation']['thresh_quiescence_cursorMag']).item(), 0])

# %%
params['simulation']['thresh_quiescence_cursorMag']
# Out:
# 0

# %%
params['simulation']
# Out:
# {'power': 1.5,
#  'idx_factor': 0,
#  'idx_avg': -1,
#  'thresh_reward': 1.5,
#  'thresh_quiescence_cursor': 0.5599999999999999,
#  'duration_quiescence_hold': 3,
#  'duration_threshold_hold': 3,
#  'win_smooth_cursor': 3,
#  'ptile_quiescence_avgVec': 0.8,
#  'thresh_quiescence_avgVec': tensor(0.9131, device='cuda:0'),
#  'thresh_quiescence_cursorDecoder': 0.30000000000000004,
#  'thresh_quiescence_cursorMag': 0}

# %% [raw]
# num_rewards_dayN, sm_dayN = bmi_idap.decoder.simple_cursor_simulation(
#     D_dayN.T,
#     CS_dayN.T,
#     idx_cursor=params['simulation']['idx_factor'],
#     idx_avg=params['simulation']['idx_avg'],
#     thresh_reward=params['simulation']['thresh_reward'],
#     thresh_quiescence_avgVec=params['simulation']['thresh_quiescence_avgVec'],
#     thresh_quiescence_cursor=params['simulation']['thresh_quiescence_cursor'],
#     duration_quiescence_hold=params['simulation']['duration_quiescence_hold'],
#     duration_threshold_hold=params['simulation']['duration_threshold_hold'],
# #     win_smooth_cursor=params['simulation']['win_smooth_cursor'],
#     win_smooth_cursor=1,
# )

# %%
num_rewards_dayN, sm_dayN = bmi_idap.decoder.simple_cursor_simulation(
    D_dayN.T, 
    CS_dayN.T, 
    M_dayN.T,
    idx_cursor=params['simulation']['idx_factor'], 
    idx_avg=params['simulation']['idx_avg'], 
    thresh_reward=params['simulation']['thresh_reward'], 
    thresh_quiescence_cursorMag=params['simulation']['thresh_quiescence_cursorMag'], 
    thresh_quiescence_cursorDecoder=params['simulation']['thresh_quiescence_cursorDecoder'], 
    duration_quiescence_hold=params['simulation']['duration_quiescence_hold'],
    duration_threshold_hold=params['simulation']['duration_threshold_hold'],
    win_smooth_cursor=1,
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 108000/108000 [00:26<00:00, 4096.17it/s]

# %%
num_rewards_dayN
# Out:
# 26

# %%
sm_dayN
# Out:
# {'rewards': array([0, 0, 0, ..., 0, 0, 0]),
#  'trial_num': array([0, 0, 0, ..., 0, 0, 0]),
#  'counter_quiescence': array([0, 0, 0, ..., 0, 0, 0]),
#  'counter_threshold': array([0, 0, 0, ..., 0, 0, 0]),
#  'CE_trial': array([1, 1, 1, ..., 1, 1, 1]),
#  'CS_quiescence': array([0, 1, 1, ..., 0, 0, 0]),
#  'cursor': array([        nan, -0.01189549, -0.01249893, ...,         nan,
#                 nan,         nan]),
#  'timeSeries_avgVec': array([       nan, 0.75183481, 0.25391358, ...,        nan,        nan,
#                nan])}

# %%
plt.figure(figsize=(20,5))
plt.plot(sm_dayN['cursor'])
plt.plot(sm_dayN['timeSeries_avgVec'], alpha=0.3)
plt.plot(sm_dayN['rewards']*0.5, linewidth=5)
# plt.plot(sm_dayN['CS_quiescence']*0.3, alpha=0.3)
# plt.plot(sm_dayN['CE_trial']*0.2)
plt.title('simulated experiment')
plt.xlabel('time (frames)');

# %%
D_dayN = torch.nan_to_num(D_dayN)

# %%
# %matplotlib notebook
plt.figure(figsize=(20,10))
plt.plot(np.arange(D_dayN.shape[1])/Fs, (D_dayN.cpu() + torch.arange(D_dayN.shape[0])[:,None]*D_dayN.std(1).mean().cpu()*7).T)
plt.xlabel('time (s)');
# Out:
# <img src="data:image/png;base64,..." width="1999.999970197678">

# %%
plt.figure(figsize=(20,5))
plt.plot(CS.T.cpu());
plt.xlabel('time (frames)')
plt.ylabel('Cosine Similarity of factors + avgVec');
# Out:
# <img src="data:image/png;base64,..." width="1999.999970197678">

# %%
# %matplotlib notebook
plt.figure()
plt.imshow(np.corrcoef(D.cpu()), vmin=-1, vmax=1, cmap='bwr');
plt.title('correlation of decoder signals (D + avgVec) + avgVec');
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# %matplotlib notebook
plt.figure()
plt.imshow(np.corrcoef(D.cpu()), vmin=-1, vmax=1, cmap='bwr');
plt.title('correlation of decoder signals (D + avgVec) + avgVec');
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
