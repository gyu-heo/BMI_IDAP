# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Imports and Paths

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import copy
import sklearn
import rastermap
import pandas as pd

import tensorly as tl
import tensorly.decomposition

# %%
dir_github        = Path(r'D:\RH_local\github').resolve()

dir_analysisFiles = Path(r'D:\RH_local\data\BMI_cage_1511_4\mouse_1511L\20230111\analysis_data').resolve()

## Directory with F.npy, stat.npy etc.
dir_s2p         = Path(r'D:\RH_local\data\BMI_cage_1511_4\mouse_1511L\20230111\analysis_data\suite2p\plane0').resolve()
# dir_s2p         = Path(r'C:\Users\Rich Hakim\Downloads\F.npy').resolve()

## Path of iscell. Can be from neural net output (iscell_NN)
path_iscell = dir_analysisFiles / 'iscell_NN_tqm.npy'

## Path of tqm (trace quality metrics). Used to get dFoF parameters
path_tqm = dir_analysisFiles / 'trace_quality.pkl'


dir_save       =  copy.copy(dir_analysisFiles)
path_save = dir_save / 'weights_day0'
# path_save = dir_save / 'weights_day0_PC2'

# %%
import sys
sys.path.append(str(dir_github))

# %load_ext autoreload
# %autoreload 2

from bnpm import torch_helpers, file_helpers, timeSeries, ca2p_preprocessing, welford_moving_2D, linear_regression, similarity

# %load_ext autoreload
# %autoreload 2
from Big_Ugly_ROI_Tracker.multiEps.multiEps_modules import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_highest_evr_var(data, factors,  hits):
    evrs = np.zeros(factors.shape[0])
    for i, factor in enumerate(factors):
        _,_,_,evr_total = similarity.orthogonalize(data, factor)
        evrs[i] = evr_total
    evrs[np.logical_not(hits)] = 0
    highest_evr_ind = np.argsort(evrs)[-1]
    return highest_evr_ind, factors[highest_evr_ind,:], evrs

def orthogonalize_simple(data, factor):
    proj_vec = similarity.proj(data, factor)[0]
    return (np.squeeze(data) - np.squeeze(proj_vec))

# %%
DEVICE = torch_helpers.set_device(use_GPU=True)
# Out:
# devices available: [_CudaDeviceProperties(name='NVIDIA GeForce RTX 2080 Ti', major=7, minor=5, total_memory=11264MB, multi_processor_count=68)]
# Using device: 'cuda:0': _CudaDeviceProperties(name='NVIDIA GeForce RTX 2080 Ti', major=7, minor=5, total_memory=11264MB, multi_processor_count=68)

# %%
iscell = np.load(path_iscell)
# spks = np.load(path_spks)

# %%
tqm = file_helpers.pickle_load(path_tqm)
dFoF_params = tqm['dFoF_params']

# %%
## == IMPORT DATA ==
F = np.load(dir_s2p / 'F.npy') # masks multiplied by data
Fneu = np.load(dir_s2p / 'Fneu.npy') # estimated neuropil signal (Fns = F - Fneu; Fo = ptile(Fns, 30); dFoF=Fns-Fo/Fo)
# iscell = np.load(dir_s2p/'iscell.npy') # probability and bool of each roi
ops = np.load(dir_s2p / 'ops.npy', allow_pickle=True) # parameters for the suite2p
spks_s2p = np.load(dir_s2p / 'spks.npy') # blind deconvolution
stat = np.load(dir_s2p / 'stat.npy', allow_pickle=True) # statistics for individual neurons 

num_frames_S2p = F.shape[1]
Fs = ops[()]['fs']

# %%
# # Oopsie!
# # Mouse g2FB: delete 43000 - 50000 frames
# F = np.delete(F, range(43000,50000), axis=1)
# Fneu = np.delete(Fneu, range(43000,50000), axis=1)

# %%
Fneu.shape
# Out:
# (3608, 108000)

# %%
frame_height = ops[()]['meanImg'].shape[0]
frame_width = ops[()]['meanImg'].shape[1]

sf = import_and_convert_to_CellReg_spatialFootprints([dir_s2p / 'stat.npy'], frame_height=frame_height, frame_width=frame_width, dtype=np.float32)[0]

# %%
F_toUse = F[iscell]
Fneu_toUse = Fneu[iscell]

# %% [raw]
# F_toUse = F.copy()
# Fneu_toUse = Fneu.copy()

# %% [markdown]
# # Prepare dFoF

# %%
win_smooth = 4
kernel_smoothing = np.zeros(win_smooth*2)
kernel_smoothing[win_smooth:] = 1
kernel_smoothing /= kernel_smoothing.sum()

# %%
# Pipeline for the NMF Strategy 
# Smooth F
F_smooth = timeSeries.convolve_along_axis(
    F_toUse,
    kernel=kernel_smoothing,
    axis=1,mode='same',
    multicore_pref=True,
    verbose=True
).astype(np.float32)

# dFoF with reduced percentile for baseline
channelOffset_correction = 500
percentile_baseline = 5
neuropil_fraction=0.7

dFoF , dF , F_neuSub , F_baseline = ca2p_preprocessing.make_dFoF(
    F=F_smooth + channelOffset_correction,
    Fneu=Fneu_toUse + channelOffset_correction,
    neuropil_fraction=neuropil_fraction,
    percentile_baseline=percentile_baseline,
    multicore_pref=True,
    verbose=True
)
# Threshold for nonnegativity
dFoF_z = dFoF / np.std(dFoF,axis=1,keepdims=True)
# Out:
# ThreadPool elapsed time : 0.12 s. Now unpacking list into array.
# Calculated convolution. Total elapsed time: 0.24 seconds
# Calculated dFoF. Total elapsed time: 0.87 seconds

# %%
# Test out rolling subtraction of the 10th percentile of the daa to remove microscope movement artifacts

ptile = 10
window = int(Fs*60*1)

# dFoF_sub_ptile = dFoF - timeSeries.rolling_percentile_pd(dFoF, ptile=ptile, window=window)
dFoF_sub_ptile = dFoF - timeSeries.rolling_percentile_rq_multicore(dFoF, ptile=ptile, window=window)
# dFoF_sub_ptile_clipped = np.clip(dFoF_sub_ptile, a_min=0, a_max=None)
dFoF_sub_ptile_clipped = np.clip(dFoF_sub_ptile, a_min=0.2, a_max=None)

# %%
dFoF_sub_ptile_clipped_ms = dFoF_sub_ptile_clipped - dFoF_sub_ptile_clipped.mean(x, keepdims=True)

# %% [markdown]
# ### Look at rastermap

# %%
import rastermap

# %%
rmap = rastermap.Rastermap(
    n_components=1,
    n_X=40,
    nPC=200,
    init='pca',
    alpha=1.0,
    K=1.0,
    mode='basic',
    verbose=True,
    annealing=True,
    constraints=2,
)

# %%
# rmap.fit(dFoF_sub_ptile)
rmap.fit(dFoF_sub_ptile_clipped)
# rmap.fit(scipy.stats.zscore(dFoF))
# Out:
# nmin 200
# 0.19745445251464844
# 6.3685524463653564
# 6.608888387680054
# 6.611880779266357
# (38, 40)
# (70,)
# 1.0
# time; iteration;  explained PC variance
# 0.00s     0        0.1543      2
# 0.02s    10        0.2925      4
# 0.04s    20        0.3391      8
# 0.06s    30        0.4415      18
# 0.09s    40        0.4870      28
# 0.11s    50        0.5403      38
# 0.13s    60        0.5404      38
# 0.15s   final      0.5404
# 0.15s upsampled    0.5404

# %%
# %matplotlib notebook

plt.figure()
# plt.imshow(dFoF_sub_ptile[rmap.isort], aspect='auto', vmax=1)
# plt.imshow(np.clip(scipy.stats.zscore(dFoF_sub_ptile, axis=1), -1,1)[rmap.isort], aspect='auto', vmax=1)
plt.imshow(dFoF_sub_ptile_clipped[rmap.isort], aspect='auto', vmin=-0.2, vmax=1)
# plt.imshow(scipy.stats.zscore(dFoF)[rmap.isort], aspect='auto', vmin=-0.1, vmax=1)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %% [raw]
# dFoF_pTileSub_rnsrWeighted = dFoF_sub_ptile_clipped/tqm['tqm']['metrics']['peter_noise_levels'][tqm['iscell_tqm']][:,None]**0.3

# %% [raw]
# discount = tqm['tqm']['metrics']['rich_nsr'][tqm['iscell_tqm']]

# %% [raw]
# discount = scipy.special.softmax(tqm['tqm']['metrics']['rich_nsr'][tqm['iscell_tqm']]/10)

# %% [raw]
# dFoF_pTileSub_rnsrWeighted = dFoF_sub_ptile_clipped

# %% [raw]
# dFoF_pTileSub_rnsrWeighted = dFoF_sub_ptile_clipped/discount[:,None]**0.3

# %% [raw]
# dFoF_pTileSub_rnsrWeighted = (dFoF_sub_ptile_clipped/dFoF_sub_ptile_clipped.std(1, keepdims=True))/discount[:,None]**1

# %% [raw]
# plt.figure()
# plt.plot(discount)

# %% [raw]
# %matplotlib notebook
#
# plt.figure()
# # plt.imshow(dFoF_sub_ptile[rmap.isort], aspect='auto', vmax=1)
# plt.imshow(
#     dFoF_pTileSub_rnsrWeighted,
#     aspect='auto',
#     vmin=0,
#     vmax=10000,
# )

# %% [markdown]
# # Run NMF

# %%
# indices_cropped = np.arange(int(Fs*60*23),dFoF_sub_ptile.shape[1])

# %%
# neural_data_toUse =dFoF / np.std(dFoF,axis=1,keepdims=True)
# neural_data_toUse = (dFoF_sub_ptile / np.std(dFoF_sub_ptile,axis=1,keepdims=True))[:,indices_cropped]
neural_data_toUse = (dFoF_sub_ptile_clipped / np.std(dFoF_sub_ptile_clipped,axis=1,keepdims=True))

# %% [raw]
# neural_data_toUse = (dFoF_sub_ptile / np.std(dFoF_sub_ptile,axis=1,keepdims=True))
# neural_data_toUse = similarity.orthogonalize(neural_data_toUse.T, traces_toOrth)[0].T
#
# neural_data_toUse = np.clip(neural_data_toUse, a_min=0, a_max=None)

# %%
tl.set_backend('pytorch')

# %%
neural_data_toUse = tl.tensor(neural_data_toUse).to('cuda')

# %%
# Roll a dice and wish for luck
rank = 10

# %% [raw]
# neural_data_toUse = dFoF_pTileSub_rnsrWeighted.copy()

# %% [raw]
# neural_data_toUse = np.clip(dFoF, a_min=0, a_max=None)

# %% [raw]
# neural_data_toUse = dFoF_sub_ptile_clipped.copy()

# %% [raw]
# neural_data_toUse = scipy.stats.zscore(np.clip(dFoF_pTileSub_rnsrWeighted, a_min=0, a_max=None), axis=1)

# %% [raw]
# %matplotlib notebook
#
# plt.figure()
# # plt.imshow(dFoF_sub_ptile[rmap.isort], aspect='auto', vmax=1)
# plt.imshow(
#     neural_data_toUse,
#     aspect='auto',
#     vmin=0,
#     vmax=4,
# )

# %% [raw]
# nmf = sklearn.decomposition.NMF(
#     n_components=rank,
#     init='nndsvda',
#     solver='cd',
#     beta_loss='frobenius',
#     tol=0.0001,
#     max_iter=200,
#     random_state=42,
# #     alpha='deprecated',
#     alpha_W=0.03,
#     alpha_H=0.01,
#     l1_ratio=0.0,
#     verbose=1,
# #     shuffle=False,
# #     regularization='deprecated'
# )
# factors_neuron_nmf = nmf.fit_transform(neural_data_toUse)

# %% [raw]
# tl.set_backend('pytorch')

# %% [raw]
# nmf = tl.decomposition.CP_NN_HALS(
#     rank=rank,
#     n_iter_max=100,
#     init='svd',
#     svd='numpy_svd',
#     tol=1e-07,
#     sparsity_coefficients=None,
#     fixed_modes=None,
#     nn_modes='all',
#     exact=False,
#     verbose=True,
#     cvg_criterion='abs_rec_error'
# )
# factors = nmf.fit_transform(torch.as_tensor(neural_data_toUse, dtype=torch.float32, device=DEVICE))
#
# # tl.decomposition.non_negative_parafac_hals(
# #             neural_data_toUse,
# #             sparsity_coefficients=[20000, 1],
# #             rank=rank,
# #             n_iter_max=5,
# #             init='svd',
# #             svd='numpy_svd',
# #             tol=1e-06,
# #         #     random_state=None,
# #             verbose=0,
# #         #     normalize_factors=False,
# #         #     return_errors=False,
# #         #     mask=None,
# #         #     cvg_criterion='abs_rec_error',
# #         #     fixed_modes=None
# #         )

# %%
factors_nmf = tl.decomposition.non_negative_parafac(
            neural_data_toUse,
            rank=rank,
            n_iter_max=1000,
            init='random',
            svd='numpy_svd', 
            tol=1e-07,
        #     random_state=None,
            verbose=1,
        #     normalize_factors=False,
        #     return_errors=False,
        #     mask=None,
        #     cvg_criterion='abs_rec_error',
        #     fixed_modes=None
        )
# Out:
# reconstruction error=0.19661574065685272
# iteration 1, reconstraction error: 0.19418169558048248, decrease = 0.0024340450763702393
# iteration 2, reconstraction error: 0.19207856059074402, decrease = 0.0021031349897384644
# iteration 3, reconstraction error: 0.19024042785167694, decrease = 0.0018381327390670776
# iteration 4, reconstraction error: 0.18862511217594147, decrease = 0.0016153156757354736
# iteration 5, reconstraction error: 0.18719330430030823, decrease = 0.0014318078756332397
# iteration 6, reconstraction error: 0.1859154850244522, decrease = 0.001277819275856018
# iteration 7, reconstraction error: 0.1847711205482483, decrease = 0.0011443644762039185
# iteration 8, reconstraction error: 0.1837397962808609, decrease = 0.0010313242673873901
# iteration 9, reconstraction error: 0.18280665576457977, decrease = 0.0009331405162811279
# iteration 10, reconstraction error: 0.18195872008800507, decrease = 0.000847935676574707
# iteration 11, reconstraction error: 0.18118572235107422, decrease = 0.0007729977369308472
# iteration 12, reconstraction error: 0.18047678470611572, decrease = 0.0007089376449584961
# iteration 13, reconstraction error: 0.1798280030488968, decrease = 0.0006487816572189331
# iteration 14, reconstraction error: 0.1792290210723877, decrease = 0.0005989819765090942
# iteration 15, reconstraction error: 0.1786775141954422, decrease = 0.0005515068769454956
# iteration 16, reconstraction error: 0.17816606163978577, decrease = 0.0005114525556564331
# iteration 17, reconstraction error: 0.1776912957429886, decrease = 0.0004747658967971802
# iteration 18, reconstraction error: 0.1772506982088089, decrease = 0.0004405975341796875
# iteration 19, reconstraction error: 0.1768384426832199, decrease = 0.00041225552558898926
# iteration 20, reconstraction error: 0.17645473778247833, decrease = 0.00038370490074157715
# iteration 21, reconstraction error: 0.17609603703022003, decrease = 0.0003587007522583008
# iteration 22, reconstraction error: 0.17576010525226593, decrease = 0.00033593177795410156
# iteration 23, reconstraction error: 0.17544426023960114, decrease = 0.0003158450126647949
# iteration 24, reconstraction error: 0.1751471906900406, decrease = 0.0002970695495605469
# iteration 25, reconstraction error: 0.17486806213855743, decrease = 0.0002791285514831543
# iteration 26, reconstraction error: 0.17460457980632782, decrease = 0.00026348233222961426
# iteration 27, reconstraction error: 0.1743558645248413, decrease = 0.00024871528148651123
# iteration 28, reconstraction error: 0.17412103712558746, decrease = 0.00023482739925384521
# iteration 29, reconstraction error: 0.17389824986457825, decrease = 0.0002227872610092163
# iteration 30, reconstraction error: 0.17368708550930023, decrease = 0.00021116435527801514
# iteration 31, reconstraction error: 0.1734875738620758, decrease = 0.00019951164722442627
# iteration 32, reconstraction error: 0.17329831421375275, decrease = 0.00018925964832305908
# iteration 33, reconstraction error: 0.17311841249465942, decrease = 0.00017990171909332275
# iteration 34, reconstraction error: 0.17294739186763763, decrease = 0.00017102062702178955
# iteration 35, reconstraction error: 0.17278340458869934, decrease = 0.00016398727893829346
# iteration 36, reconstraction error: 0.17262928187847137, decrease = 0.0001541227102279663
# iteration 37, reconstraction error: 0.17248031497001648, decrease = 0.00014896690845489502
# iteration 38, reconstraction error: 0.17233887314796448, decrease = 0.00014144182205200195
# iteration 39, reconstraction error: 0.17220357060432434, decrease = 0.00013530254364013672
# iteration 40, reconstraction error: 0.17207345366477966, decrease = 0.00013011693954467773
# iteration 41, reconstraction error: 0.17194995284080505, decrease = 0.00012350082397460938
# iteration 42, reconstraction error: 0.1718326061964035, decrease = 0.00011734664440155029
# iteration 43, reconstraction error: 0.17171809077262878, decrease = 0.00011451542377471924
# iteration 44, reconstraction error: 0.1716097593307495, decrease = 0.00010833144187927246
# iteration 45, reconstraction error: 0.17150472104549408, decrease = 0.00010503828525543213
# iteration 46, reconstraction error: 0.1714049130678177, decrease = 9.98079776763916e-05
# iteration 47, reconstraction error: 0.1713094264268875, decrease = 9.548664093017578e-05
# iteration 48, reconstraction error: 0.17121675610542297, decrease = 9.267032146453857e-05
# iteration 49, reconstraction error: 0.17112790048122406, decrease = 8.885562419891357e-05
# iteration 50, reconstraction error: 0.17104238271713257, decrease = 8.55177640914917e-05
# iteration 51, reconstraction error: 0.1709606945514679, decrease = 8.168816566467285e-05
# iteration 52, reconstraction error: 0.17088139057159424, decrease = 7.930397987365723e-05
# iteration 53, reconstraction error: 0.170805424451828, decrease = 7.596611976623535e-05
# iteration 54, reconstraction error: 0.17073185741901398, decrease = 7.356703281402588e-05
# iteration 55, reconstraction error: 0.17066116631031036, decrease = 7.069110870361328e-05
# iteration 56, reconstraction error: 0.17059284448623657, decrease = 6.83218240737915e-05
# iteration 57, reconstraction error: 0.17052742838859558, decrease = 6.541609764099121e-05
# iteration 58, reconstraction error: 0.1704639196395874, decrease = 6.350874900817871e-05
# iteration 59, reconstraction error: 0.17040233314037323, decrease = 6.158649921417236e-05
# iteration 60, reconstraction error: 0.17034265398979187, decrease = 5.967915058135986e-05
# iteration 61, reconstraction error: 0.17028537392616272, decrease = 5.728006362915039e-05
# iteration 62, reconstraction error: 0.17023003101348877, decrease = 5.5342912673950195e-05
# iteration 63, reconstraction error: 0.17017565667629242, decrease = 5.43743371963501e-05
# iteration 64, reconstraction error: 0.17012512683868408, decrease = 5.05298376083374e-05
# iteration 65, reconstraction error: 0.17007459700107574, decrease = 5.05298376083374e-05
# iteration 66, reconstraction error: 0.17002549767494202, decrease = 4.909932613372803e-05
# iteration 67, reconstraction error: 0.1699783205986023, decrease = 4.717707633972168e-05
# iteration 68, reconstraction error: 0.16993358731269836, decrease = 4.4733285903930664e-05
# iteration 69, reconstraction error: 0.16988933086395264, decrease = 4.425644874572754e-05
# iteration 70, reconstraction error: 0.16984698176383972, decrease = 4.234910011291504e-05
# iteration 71, reconstraction error: 0.1698051244020462, decrease = 4.1857361793518066e-05
# iteration 72, reconstraction error: 0.1697642207145691, decrease = 4.0903687477111816e-05
# iteration 73, reconstraction error: 0.16972576081752777, decrease = 3.84598970413208e-05
# iteration 74, reconstraction error: 0.16968728601932526, decrease = 3.847479820251465e-05
# iteration 75, reconstraction error: 0.16965124011039734, decrease = 3.604590892791748e-05
# iteration 76, reconstraction error: 0.16961567103862762, decrease = 3.5569071769714355e-05
# iteration 77, reconstraction error: 0.1695810705423355, decrease = 3.460049629211426e-05
# iteration 78, reconstraction error: 0.1695479154586792, decrease = 3.3155083656311035e-05
# iteration 79, reconstraction error: 0.1695147454738617, decrease = 3.316998481750488e-05
# iteration 80, reconstraction error: 0.16948257386684418, decrease = 3.217160701751709e-05
# iteration 81, reconstraction error: 0.16945233941078186, decrease = 3.0234456062316895e-05
# iteration 82, reconstraction error: 0.16942209005355835, decrease = 3.0249357223510742e-05
# iteration 83, reconstraction error: 0.16939379274845123, decrease = 2.82973051071167e-05
# iteration 84, reconstraction error: 0.16936549544334412, decrease = 2.82973051071167e-05
# iteration 85, reconstraction error: 0.169337660074234, decrease = 2.7835369110107422e-05
# iteration 86, reconstraction error: 0.1693117916584015, decrease = 2.586841583251953e-05
# iteration 87, reconstraction error: 0.16928495466709137, decrease = 2.683699131011963e-05
# iteration 88, reconstraction error: 0.16925907135009766, decrease = 2.588331699371338e-05
# iteration 89, reconstraction error: 0.16923414170742035, decrease = 2.492964267730713e-05
# iteration 90, reconstraction error: 0.16921070218086243, decrease = 2.3439526557922363e-05
# iteration 91, reconstraction error: 0.1691872626543045, decrease = 2.3439526557922363e-05
# iteration 92, reconstraction error: 0.1691637933254242, decrease = 2.346932888031006e-05
# iteration 93, reconstraction error: 0.16914230585098267, decrease = 2.148747444152832e-05
# iteration 94, reconstraction error: 0.16912031173706055, decrease = 2.199411392211914e-05
# iteration 95, reconstraction error: 0.16909879446029663, decrease = 2.1517276763916016e-05
# iteration 96, reconstraction error: 0.1690787672996521, decrease = 2.002716064453125e-05
# iteration 97, reconstraction error: 0.16905921697616577, decrease = 1.9550323486328125e-05
# iteration 98, reconstraction error: 0.16903916001319885, decrease = 2.0056962966918945e-05
# iteration 99, reconstraction error: 0.16902057826519012, decrease = 1.8581748008728027e-05
# iteration 100, reconstraction error: 0.169001504778862, decrease = 1.9073486328125e-05
# iteration 101, reconstraction error: 0.16898438334465027, decrease = 1.7121434211730957e-05
# iteration 102, reconstraction error: 0.16896578669548035, decrease = 1.8596649169921875e-05
# iteration 103, reconstraction error: 0.1689486801624298, decrease = 1.710653305053711e-05
# iteration 104, reconstraction error: 0.16893205046653748, decrease = 1.6629695892333984e-05
# iteration 105, reconstraction error: 0.16891540586948395, decrease = 1.6644597053527832e-05
# iteration 106, reconstraction error: 0.16889925301074982, decrease = 1.615285873413086e-05
# iteration 107, reconstraction error: 0.16888310015201569, decrease = 1.615285873413086e-05
# iteration 108, reconstraction error: 0.16886793076992035, decrease = 1.5169382095336914e-05
# iteration 109, reconstraction error: 0.16885323822498322, decrease = 1.4692544937133789e-05
# iteration 110, reconstraction error: 0.16883854568004608, decrease = 1.4692544937133789e-05
# iteration 111, reconstraction error: 0.16882386803627014, decrease = 1.4677643775939941e-05
# iteration 112, reconstraction error: 0.1688096672296524, decrease = 1.4200806617736816e-05
# iteration 113, reconstraction error: 0.16879546642303467, decrease = 1.4200806617736816e-05
# iteration 114, reconstraction error: 0.16878272593021393, decrease = 1.2740492820739746e-05
# iteration 115, reconstraction error: 0.16876952350139618, decrease = 1.3202428817749023e-05
# iteration 116, reconstraction error: 0.16875776648521423, decrease = 1.17570161819458e-05
# iteration 117, reconstraction error: 0.1687445342540741, decrease = 1.3232231140136719e-05
# iteration 118, reconstraction error: 0.16873180866241455, decrease = 1.2725591659545898e-05
# iteration 119, reconstraction error: 0.1687195599079132, decrease = 1.2248754501342773e-05
# iteration 120, reconstraction error: 0.16870827972888947, decrease = 1.1280179023742676e-05
# iteration 121, reconstraction error: 0.16869701445102692, decrease = 1.1265277862548828e-05
# iteration 122, reconstraction error: 0.16868525743484497, decrease = 1.17570161819458e-05
# iteration 123, reconstraction error: 0.16867497563362122, decrease = 1.0281801223754883e-05
# iteration 124, reconstraction error: 0.16866369545459747, decrease = 1.1280179023742676e-05
# iteration 125, reconstraction error: 0.16865290701389313, decrease = 1.0788440704345703e-05
# iteration 126, reconstraction error: 0.16864211857318878, decrease = 1.0788440704345703e-05
# iteration 127, reconstraction error: 0.16863282024860382, decrease = 9.298324584960938e-06
# iteration 128, reconstraction error: 0.16862252354621887, decrease = 1.029670238494873e-05
# iteration 129, reconstraction error: 0.16861321032047272, decrease = 9.313225746154785e-06
# iteration 130, reconstraction error: 0.16860340535640717, decrease = 9.804964065551758e-06
# iteration 131, reconstraction error: 0.1685936003923416, decrease = 9.804964065551758e-06
# iteration 132, reconstraction error: 0.16858527064323425, decrease = 8.32974910736084e-06
# iteration 133, reconstraction error: 0.1685754656791687, decrease = 9.804964065551758e-06
# iteration 134, reconstraction error: 0.16856761276721954, decrease = 7.852911949157715e-06
# iteration 135, reconstraction error: 0.1685582995414734, decrease = 9.313225746154785e-06
# iteration 136, reconstraction error: 0.16854946315288544, decrease = 8.83638858795166e-06
# iteration 137, reconstraction error: 0.16854014992713928, decrease = 9.313225746154785e-06
# iteration 138, reconstraction error: 0.16853280365467072, decrease = 7.3462724685668945e-06
# iteration 139, reconstraction error: 0.16852396726608276, decrease = 8.83638858795166e-06
# iteration 140, reconstraction error: 0.1685175895690918, decrease = 6.377696990966797e-06
# iteration 141, reconstraction error: 0.16850973665714264, decrease = 7.852911949157715e-06
# iteration 142, reconstraction error: 0.16850091516971588, decrease = 8.821487426757812e-06
# iteration 143, reconstraction error: 0.16849353909492493, decrease = 7.37607479095459e-06
# iteration 144, reconstraction error: 0.16848668456077576, decrease = 6.854534149169922e-06
# iteration 145, reconstraction error: 0.1684788465499878, decrease = 7.838010787963867e-06
# iteration 146, reconstraction error: 0.16847196221351624, decrease = 6.884336471557617e-06
# iteration 147, reconstraction error: 0.16846510767936707, decrease = 6.854534149169922e-06
# iteration 148, reconstraction error: 0.1684572398662567, decrease = 7.867813110351562e-06
# iteration 149, reconstraction error: 0.16845038533210754, decrease = 6.854534149169922e-06
# iteration 150, reconstraction error: 0.16844448447227478, decrease = 5.900859832763672e-06
# iteration 151, reconstraction error: 0.16843761503696442, decrease = 6.8694353103637695e-06
# iteration 152, reconstraction error: 0.16843074560165405, decrease = 6.8694353103637695e-06
# iteration 153, reconstraction error: 0.16842436790466309, decrease = 6.377696990966797e-06
# iteration 154, reconstraction error: 0.16841749846935272, decrease = 6.8694353103637695e-06
# iteration 155, reconstraction error: 0.16841308772563934, decrease = 4.410743713378906e-06
# iteration 156, reconstraction error: 0.16840621829032898, decrease = 6.8694353103637695e-06
# iteration 157, reconstraction error: 0.16839982569217682, decrease = 6.3925981521606445e-06
# iteration 158, reconstraction error: 0.16839344799518585, decrease = 6.377696990966797e-06
# iteration 159, reconstraction error: 0.16838756203651428, decrease = 5.885958671569824e-06
# iteration 160, reconstraction error: 0.16838215291500092, decrease = 5.409121513366699e-06
# iteration 161, reconstraction error: 0.16837628185749054, decrease = 5.8710575103759766e-06
# iteration 162, reconstraction error: 0.16837087273597717, decrease = 5.409121513366699e-06
# iteration 163, reconstraction error: 0.168364480137825, decrease = 6.3925981521606445e-06
# iteration 164, reconstraction error: 0.16835956275463104, decrease = 4.9173831939697266e-06
# iteration 165, reconstraction error: 0.16835418343544006, decrease = 5.379319190979004e-06
# iteration 166, reconstraction error: 0.1683482825756073, decrease = 5.900859832763672e-06
# iteration 167, reconstraction error: 0.16834385693073273, decrease = 4.425644874572754e-06
# iteration 168, reconstraction error: 0.16833895444869995, decrease = 4.902482032775879e-06
# iteration 169, reconstraction error: 0.1683330535888672, decrease = 5.900859832763672e-06
# iteration 170, reconstraction error: 0.1683271825313568, decrease = 5.8710575103759766e-06
# iteration 171, reconstraction error: 0.16832226514816284, decrease = 4.9173831939697266e-06
# iteration 172, reconstraction error: 0.16831783950328827, decrease = 4.425644874572754e-06
# iteration 173, reconstraction error: 0.1683129221200943, decrease = 4.9173831939697266e-06
# iteration 174, reconstraction error: 0.16830851137638092, decrease = 4.410743713378906e-06
# iteration 175, reconstraction error: 0.16830310225486755, decrease = 5.409121513366699e-06
# iteration 176, reconstraction error: 0.16829818487167358, decrease = 4.9173831939697266e-06
# iteration 177, reconstraction error: 0.1682928055524826, decrease = 5.379319190979004e-06
# iteration 178, reconstraction error: 0.16828837990760803, decrease = 4.425644874572754e-06
# iteration 179, reconstraction error: 0.16828395426273346, decrease = 4.425644874572754e-06
# iteration 180, reconstraction error: 0.1682790368795395, decrease = 4.9173831939697266e-06
# iteration 181, reconstraction error: 0.1682746261358261, decrease = 4.410743713378906e-06
# iteration 182, reconstraction error: 0.16826921701431274, decrease = 5.409121513366699e-06
# iteration 183, reconstraction error: 0.16826577484607697, decrease = 3.4421682357788086e-06
# iteration 184, reconstraction error: 0.1682613492012024, decrease = 4.425644874572754e-06
# iteration 185, reconstraction error: 0.168256938457489, decrease = 4.410743713378906e-06
# iteration 186, reconstraction error: 0.16825251281261444, decrease = 4.425644874572754e-06
# iteration 187, reconstraction error: 0.16824808716773987, decrease = 4.425644874572754e-06
# iteration 188, reconstraction error: 0.1682436615228653, decrease = 4.425644874572754e-06
# iteration 189, reconstraction error: 0.16823925077915192, decrease = 4.410743713378906e-06
# iteration 190, reconstraction error: 0.16823531687259674, decrease = 3.933906555175781e-06
# iteration 191, reconstraction error: 0.16823138296604156, decrease = 3.933906555175781e-06
# iteration 192, reconstraction error: 0.1682274490594864, decrease = 3.933906555175781e-06
# iteration 193, reconstraction error: 0.1682235151529312, decrease = 3.933906555175781e-06
# iteration 194, reconstraction error: 0.16821910440921783, decrease = 4.410743713378906e-06
# iteration 195, reconstraction error: 0.16821418702602386, decrease = 4.9173831939697266e-06
# iteration 196, reconstraction error: 0.1682102531194687, decrease = 3.933906555175781e-06
# iteration 197, reconstraction error: 0.16820533573627472, decrease = 4.9173831939697266e-06
# iteration 198, reconstraction error: 0.16820190846920013, decrease = 3.427267074584961e-06
# iteration 199, reconstraction error: 0.16819846630096436, decrease = 3.4421682357788086e-06
# iteration 200, reconstraction error: 0.16819404065608978, decrease = 4.425644874572754e-06
# iteration 201, reconstraction error: 0.168190598487854, decrease = 3.4421682357788086e-06
# iteration 202, reconstraction error: 0.16818666458129883, decrease = 3.933906555175781e-06
# iteration 203, reconstraction error: 0.16818274557590485, decrease = 3.919005393981934e-06
# iteration 204, reconstraction error: 0.16817831993103027, decrease = 4.425644874572754e-06
# iteration 205, reconstraction error: 0.1681748777627945, decrease = 3.4421682357788086e-06
# iteration 206, reconstraction error: 0.16817143559455872, decrease = 3.4421682357788086e-06
# iteration 207, reconstraction error: 0.16816702485084534, decrease = 4.410743713378906e-06
# iteration 208, reconstraction error: 0.16816259920597076, decrease = 4.425644874572754e-06
# iteration 209, reconstraction error: 0.1681591421365738, decrease = 3.4570693969726562e-06
# iteration 210, reconstraction error: 0.168155699968338, decrease = 3.4421682357788086e-06
# iteration 211, reconstraction error: 0.16815176606178284, decrease = 3.933906555175781e-06
# iteration 212, reconstraction error: 0.16814686357975006, decrease = 4.902482032775879e-06
# iteration 213, reconstraction error: 0.16814342141151428, decrease = 3.4421682357788086e-06
# iteration 214, reconstraction error: 0.1681394875049591, decrease = 3.933906555175781e-06
# iteration 215, reconstraction error: 0.16813604533672333, decrease = 3.4421682357788086e-06
# iteration 216, reconstraction error: 0.16813358664512634, decrease = 2.4586915969848633e-06
# iteration 217, reconstraction error: 0.16812819242477417, decrease = 5.3942203521728516e-06
# iteration 218, reconstraction error: 0.1681252270936966, decrease = 2.9653310775756836e-06
# iteration 219, reconstraction error: 0.1681222766637802, decrease = 2.950429916381836e-06
# iteration 220, reconstraction error: 0.16811686754226685, decrease = 5.409121513366699e-06
# iteration 221, reconstraction error: 0.16811342537403107, decrease = 3.4421682357788086e-06
# iteration 222, reconstraction error: 0.16811047494411469, decrease = 2.950429916381836e-06
# iteration 223, reconstraction error: 0.1681060642004013, decrease = 4.410743713378906e-06
# iteration 224, reconstraction error: 0.16810360550880432, decrease = 2.4586915969848633e-06
# iteration 225, reconstraction error: 0.16809916496276855, decrease = 4.4405460357666016e-06
# iteration 226, reconstraction error: 0.16809473931789398, decrease = 4.425644874572754e-06
# iteration 227, reconstraction error: 0.168092280626297, decrease = 2.4586915969848633e-06
# iteration 228, reconstraction error: 0.16808834671974182, decrease = 3.933906555175781e-06
# iteration 229, reconstraction error: 0.16808442771434784, decrease = 3.919005393981934e-06
# iteration 230, reconstraction error: 0.16808098554611206, decrease = 3.4421682357788086e-06
# iteration 231, reconstraction error: 0.1680770367383957, decrease = 3.948807716369629e-06
# iteration 232, reconstraction error: 0.1680735945701599, decrease = 3.4421682357788086e-06
# iteration 233, reconstraction error: 0.16807015240192413, decrease = 3.4421682357788086e-06
# iteration 234, reconstraction error: 0.16806621849536896, decrease = 3.933906555175781e-06
# iteration 235, reconstraction error: 0.16806229948997498, decrease = 3.919005393981934e-06
# iteration 236, reconstraction error: 0.168058842420578, decrease = 3.4570693969726562e-06
# iteration 237, reconstraction error: 0.16805540025234222, decrease = 3.4421682357788086e-06
# iteration 238, reconstraction error: 0.16805097460746765, decrease = 4.425644874572754e-06
# iteration 239, reconstraction error: 0.16804753243923187, decrease = 3.4421682357788086e-06
# iteration 240, reconstraction error: 0.1680440753698349, decrease = 3.4570693969726562e-06
# iteration 241, reconstraction error: 0.16804063320159912, decrease = 3.4421682357788086e-06
# iteration 242, reconstraction error: 0.16803671419620514, decrease = 3.919005393981934e-06
# iteration 243, reconstraction error: 0.16803278028964996, decrease = 3.933906555175781e-06
# iteration 244, reconstraction error: 0.16802933812141418, decrease = 3.4421682357788086e-06
# iteration 245, reconstraction error: 0.1680258810520172, decrease = 3.4570693969726562e-06
# iteration 246, reconstraction error: 0.16802194714546204, decrease = 3.933906555175781e-06
# iteration 247, reconstraction error: 0.16801850497722626, decrease = 3.4421682357788086e-06
# iteration 248, reconstraction error: 0.16801407933235168, decrease = 4.425644874572754e-06
# iteration 249, reconstraction error: 0.1680106371641159, decrease = 3.4421682357788086e-06
# iteration 250, reconstraction error: 0.16800719499588013, decrease = 3.4421682357788086e-06
# iteration 251, reconstraction error: 0.16800326108932495, decrease = 3.933906555175781e-06
# iteration 252, reconstraction error: 0.16800029575824738, decrease = 2.9653310775756836e-06
# iteration 253, reconstraction error: 0.1679958701133728, decrease = 4.425644874572754e-06
# iteration 254, reconstraction error: 0.16799244284629822, decrease = 3.427267074584961e-06
# iteration 255, reconstraction error: 0.16798800230026245, decrease = 4.4405460357666016e-06
# iteration 256, reconstraction error: 0.16798505187034607, decrease = 2.950429916381836e-06
# iteration 257, reconstraction error: 0.1679806262254715, decrease = 4.425644874572754e-06
# iteration 258, reconstraction error: 0.16797718405723572, decrease = 3.4421682357788086e-06
# iteration 259, reconstraction error: 0.16797372698783875, decrease = 3.4570693969726562e-06
# iteration 260, reconstraction error: 0.16796979308128357, decrease = 3.933906555175781e-06
# iteration 261, reconstraction error: 0.1679658740758896, decrease = 3.919005393981934e-06
# iteration 262, reconstraction error: 0.167962908744812, decrease = 2.9653310775756836e-06
# iteration 263, reconstraction error: 0.16795799136161804, decrease = 4.9173831939697266e-06
# iteration 264, reconstraction error: 0.16795504093170166, decrease = 2.950429916381836e-06
# iteration 265, reconstraction error: 0.1679506003856659, decrease = 4.4405460357666016e-06
# iteration 266, reconstraction error: 0.16794666647911072, decrease = 3.933906555175781e-06
# iteration 267, reconstraction error: 0.16794370114803314, decrease = 2.9653310775756836e-06
# iteration 268, reconstraction error: 0.16793978214263916, decrease = 3.919005393981934e-06
# iteration 269, reconstraction error: 0.16793584823608398, decrease = 3.933906555175781e-06
# iteration 270, reconstraction error: 0.16793140769004822, decrease = 4.4405460357666016e-06
# iteration 271, reconstraction error: 0.16792796552181244, decrease = 3.4421682357788086e-06
# iteration 272, reconstraction error: 0.16792452335357666, decrease = 3.4421682357788086e-06
# iteration 273, reconstraction error: 0.1679205745458603, decrease = 3.948807716369629e-06
# iteration 274, reconstraction error: 0.1679161638021469, decrease = 4.410743713378906e-06
# iteration 275, reconstraction error: 0.16791367530822754, decrease = 2.4884939193725586e-06
# iteration 276, reconstraction error: 0.16790877282619476, decrease = 4.902482032775879e-06
# iteration 277, reconstraction error: 0.1679053157567978, decrease = 3.4570693969726562e-06
# iteration 278, reconstraction error: 0.16790089011192322, decrease = 4.425644874572754e-06
# iteration 279, reconstraction error: 0.16789744794368744, decrease = 3.4421682357788086e-06
# iteration 280, reconstraction error: 0.16789251565933228, decrease = 4.932284355163574e-06
# iteration 281, reconstraction error: 0.1678885817527771, decrease = 3.933906555175781e-06
# iteration 282, reconstraction error: 0.16788513958454132, decrease = 3.4421682357788086e-06
# iteration 283, reconstraction error: 0.16788120567798615, decrease = 3.933906555175781e-06
# iteration 284, reconstraction error: 0.16787725687026978, decrease = 3.948807716369629e-06
# iteration 285, reconstraction error: 0.167873814702034, decrease = 3.4421682357788086e-06
# iteration 286, reconstraction error: 0.16786937415599823, decrease = 4.4405460357666016e-06
# iteration 287, reconstraction error: 0.16786445677280426, decrease = 4.9173831939697266e-06
# iteration 288, reconstraction error: 0.16786149144172668, decrease = 2.9653310775756836e-06
# iteration 289, reconstraction error: 0.1678575575351715, decrease = 3.933906555175781e-06
# iteration 290, reconstraction error: 0.16785362362861633, decrease = 3.933906555175781e-06
# iteration 291, reconstraction error: 0.16784968972206116, decrease = 3.933906555175781e-06
# iteration 292, reconstraction error: 0.1678457409143448, decrease = 3.948807716369629e-06
# iteration 293, reconstraction error: 0.16784131526947021, decrease = 4.425644874572754e-06
# iteration 294, reconstraction error: 0.16783785820007324, decrease = 3.4570693969726562e-06
# iteration 295, reconstraction error: 0.16783343255519867, decrease = 4.425644874572754e-06
# iteration 296, reconstraction error: 0.1678299754858017, decrease = 3.4570693969726562e-06
# iteration 297, reconstraction error: 0.16782556474208832, decrease = 4.410743713378906e-06
# iteration 298, reconstraction error: 0.16782161593437195, decrease = 3.948807716369629e-06
# iteration 299, reconstraction error: 0.1678161919116974, decrease = 5.424022674560547e-06
# iteration 300, reconstraction error: 0.167813241481781, decrease = 2.950429916381836e-06
# iteration 301, reconstraction error: 0.16780880093574524, decrease = 4.4405460357666016e-06
# iteration 302, reconstraction error: 0.16780585050582886, decrease = 2.950429916381836e-06
# iteration 303, reconstraction error: 0.1678014099597931, decrease = 4.4405460357666016e-06
# iteration 304, reconstraction error: 0.16779747605323792, decrease = 3.933906555175781e-06
# iteration 305, reconstraction error: 0.16779352724552155, decrease = 3.948807716369629e-06
# iteration 306, reconstraction error: 0.16778908669948578, decrease = 4.4405460357666016e-06
# iteration 307, reconstraction error: 0.1677856594324112, decrease = 3.427267074584961e-06
# iteration 308, reconstraction error: 0.16778072714805603, decrease = 4.932284355163574e-06
# iteration 309, reconstraction error: 0.16777679324150085, decrease = 3.933906555175781e-06
# iteration 310, reconstraction error: 0.1677718609571457, decrease = 4.932284355163574e-06
# iteration 311, reconstraction error: 0.16776889562606812, decrease = 2.9653310775756836e-06
# iteration 312, reconstraction error: 0.16776446998119354, decrease = 4.425644874572754e-06
# iteration 313, reconstraction error: 0.16776002943515778, decrease = 4.4405460357666016e-06
# iteration 314, reconstraction error: 0.1677565723657608, decrease = 3.4570693969726562e-06
# iteration 315, reconstraction error: 0.16775166988372803, decrease = 4.902482032775879e-06
# iteration 316, reconstraction error: 0.16774821281433105, decrease = 3.4570693969726562e-06
# iteration 317, reconstraction error: 0.16774426400661469, decrease = 3.948807716369629e-06
# iteration 318, reconstraction error: 0.16773934662342072, decrease = 4.9173831939697266e-06
# iteration 319, reconstraction error: 0.16773539781570435, decrease = 3.948807716369629e-06
# iteration 320, reconstraction error: 0.16773144900798798, decrease = 3.948807716369629e-06
# iteration 321, reconstraction error: 0.1677265167236328, decrease = 4.932284355163574e-06
# iteration 322, reconstraction error: 0.16772307455539703, decrease = 3.4421682357788086e-06
# iteration 323, reconstraction error: 0.16771912574768066, decrease = 3.948807716369629e-06
# iteration 324, reconstraction error: 0.1677141934633255, decrease = 4.932284355163574e-06
# iteration 325, reconstraction error: 0.16770978271961212, decrease = 4.410743713378906e-06
# iteration 326, reconstraction error: 0.16770681738853455, decrease = 2.9653310775756836e-06
# iteration 327, reconstraction error: 0.16770286858081818, decrease = 3.948807716369629e-06
# iteration 328, reconstraction error: 0.167697936296463, decrease = 4.932284355163574e-06
# iteration 329, reconstraction error: 0.16769400238990784, decrease = 3.933906555175781e-06
# iteration 330, reconstraction error: 0.16769005358219147, decrease = 3.948807716369629e-06
# iteration 331, reconstraction error: 0.1676861047744751, decrease = 3.948807716369629e-06
# iteration 332, reconstraction error: 0.16768166422843933, decrease = 4.4405460357666016e-06
# iteration 333, reconstraction error: 0.16767723858356476, decrease = 4.425644874572754e-06
# iteration 334, reconstraction error: 0.167672798037529, decrease = 4.4405460357666016e-06
# iteration 335, reconstraction error: 0.16766934096813202, decrease = 3.4570693969726562e-06
# iteration 336, reconstraction error: 0.16766442358493805, decrease = 4.9173831939697266e-06
# iteration 337, reconstraction error: 0.16766047477722168, decrease = 3.948807716369629e-06
# iteration 338, reconstraction error: 0.1676570326089859, decrease = 3.4421682357788086e-06
# iteration 339, reconstraction error: 0.16765210032463074, decrease = 4.932284355163574e-06
# iteration 340, reconstraction error: 0.16764716804027557, decrease = 4.932284355163574e-06
# iteration 341, reconstraction error: 0.1676446944475174, decrease = 2.473592758178711e-06
# iteration 342, reconstraction error: 0.16763976216316223, decrease = 4.932284355163574e-06
# iteration 343, reconstraction error: 0.16763532161712646, decrease = 4.4405460357666016e-06
# iteration 344, reconstraction error: 0.16763187944889069, decrease = 3.4421682357788086e-06
# iteration 345, reconstraction error: 0.16762793064117432, decrease = 3.948807716369629e-06
# iteration 346, reconstraction error: 0.16762398183345795, decrease = 3.948807716369629e-06
# iteration 347, reconstraction error: 0.16762003302574158, decrease = 3.948807716369629e-06
# iteration 348, reconstraction error: 0.1676146239042282, decrease = 5.409121513366699e-06
# iteration 349, reconstraction error: 0.16761118173599243, decrease = 3.4421682357788086e-06
# iteration 350, reconstraction error: 0.16760674118995667, decrease = 4.4405460357666016e-06
# iteration 351, reconstraction error: 0.1676032841205597, decrease = 3.4570693969726562e-06
# iteration 352, reconstraction error: 0.16759884357452393, decrease = 4.4405460357666016e-06
# iteration 353, reconstraction error: 0.16759440302848816, decrease = 4.4405460357666016e-06
# iteration 354, reconstraction error: 0.1675904542207718, decrease = 3.948807716369629e-06
# iteration 355, reconstraction error: 0.16758650541305542, decrease = 3.948807716369629e-06
# iteration 356, reconstraction error: 0.16758206486701965, decrease = 4.4405460357666016e-06
# iteration 357, reconstraction error: 0.16757862269878387, decrease = 3.4421682357788086e-06
# iteration 358, reconstraction error: 0.1675741821527481, decrease = 4.4405460357666016e-06
# iteration 359, reconstraction error: 0.16757072508335114, decrease = 3.4570693969726562e-06
# iteration 360, reconstraction error: 0.16756677627563477, decrease = 3.948807716369629e-06
# iteration 361, reconstraction error: 0.167562335729599, decrease = 4.4405460357666016e-06
# iteration 362, reconstraction error: 0.16755791008472443, decrease = 4.425644874572754e-06
# iteration 363, reconstraction error: 0.16755445301532745, decrease = 3.4570693969726562e-06
# iteration 364, reconstraction error: 0.1675500124692917, decrease = 4.4405460357666016e-06
# iteration 365, reconstraction error: 0.16754606366157532, decrease = 3.948807716369629e-06
# iteration 366, reconstraction error: 0.16754162311553955, decrease = 4.4405460357666016e-06
# iteration 367, reconstraction error: 0.16753816604614258, decrease = 3.4570693969726562e-06
# iteration 368, reconstraction error: 0.1675337255001068, decrease = 4.4405460357666016e-06
# iteration 369, reconstraction error: 0.16753126680850983, decrease = 2.4586915969848633e-06
# iteration 370, reconstraction error: 0.16752633452415466, decrease = 4.932284355163574e-06
# iteration 371, reconstraction error: 0.1675218790769577, decrease = 4.455447196960449e-06
# iteration 372, reconstraction error: 0.16751843690872192, decrease = 3.4421682357788086e-06
# iteration 373, reconstraction error: 0.16751448810100555, decrease = 3.948807716369629e-06
# iteration 374, reconstraction error: 0.16751053929328918, decrease = 3.948807716369629e-06
# iteration 375, reconstraction error: 0.16750609874725342, decrease = 4.4405460357666016e-06
# iteration 376, reconstraction error: 0.16750264167785645, decrease = 3.4570693969726562e-06
# iteration 377, reconstraction error: 0.16749918460845947, decrease = 3.4570693969726562e-06
# iteration 378, reconstraction error: 0.1674957275390625, decrease = 3.4570693969726562e-06
# iteration 379, reconstraction error: 0.16749079525470734, decrease = 4.932284355163574e-06
# iteration 380, reconstraction error: 0.16748635470867157, decrease = 4.4405460357666016e-06
# iteration 381, reconstraction error: 0.1674824059009552, decrease = 3.948807716369629e-06
# iteration 382, reconstraction error: 0.16747894883155823, decrease = 3.4570693969726562e-06
# iteration 383, reconstraction error: 0.16747500002384186, decrease = 3.948807716369629e-06
# iteration 384, reconstraction error: 0.16747106611728668, decrease = 3.933906555175781e-06
# iteration 385, reconstraction error: 0.1674685776233673, decrease = 2.4884939193725586e-06
# iteration 386, reconstraction error: 0.16746415197849274, decrease = 4.425644874572754e-06
# iteration 387, reconstraction error: 0.16746069490909576, decrease = 3.4570693969726562e-06
# iteration 388, reconstraction error: 0.1674567461013794, decrease = 3.948807716369629e-06
# iteration 389, reconstraction error: 0.16745181381702423, decrease = 4.932284355163574e-06
# iteration 390, reconstraction error: 0.16744835674762726, decrease = 3.4570693969726562e-06
# iteration 391, reconstraction error: 0.16744489967823029, decrease = 3.4570693969726562e-06
# iteration 392, reconstraction error: 0.1674414426088333, decrease = 3.4570693969726562e-06
# iteration 393, reconstraction error: 0.16743749380111694, decrease = 3.948807716369629e-06
# iteration 394, reconstraction error: 0.16743354499340057, decrease = 3.948807716369629e-06
# iteration 395, reconstraction error: 0.1674295961856842, decrease = 3.948807716369629e-06
# iteration 396, reconstraction error: 0.16742564737796783, decrease = 3.948807716369629e-06
# iteration 397, reconstraction error: 0.16742169857025146, decrease = 3.948807716369629e-06
# iteration 398, reconstraction error: 0.1674182415008545, decrease = 3.4570693969726562e-06
# iteration 399, reconstraction error: 0.16741478443145752, decrease = 3.4570693969726562e-06
# iteration 400, reconstraction error: 0.16741083562374115, decrease = 3.948807716369629e-06
# iteration 401, reconstraction error: 0.16740737855434418, decrease = 3.4570693969726562e-06
# iteration 402, reconstraction error: 0.1674029380083084, decrease = 4.4405460357666016e-06
# iteration 403, reconstraction error: 0.16739948093891144, decrease = 3.4570693969726562e-06
# iteration 404, reconstraction error: 0.16739602386951447, decrease = 3.4570693969726562e-06
# iteration 405, reconstraction error: 0.1673925668001175, decrease = 3.4570693969726562e-06
# iteration 406, reconstraction error: 0.16738811135292053, decrease = 4.455447196960449e-06
# iteration 407, reconstraction error: 0.16738565266132355, decrease = 2.4586915969848633e-06
# iteration 408, reconstraction error: 0.1673811972141266, decrease = 4.455447196960449e-06
# iteration 409, reconstraction error: 0.16737675666809082, decrease = 4.4405460357666016e-06
# iteration 410, reconstraction error: 0.16737428307533264, decrease = 2.473592758178711e-06
# iteration 411, reconstraction error: 0.16737133264541626, decrease = 2.950429916381836e-06
# iteration 412, reconstraction error: 0.1673668771982193, decrease = 4.455447196960449e-06
# iteration 413, reconstraction error: 0.16736391186714172, decrease = 2.9653310775756836e-06
# iteration 414, reconstraction error: 0.16735947132110596, decrease = 4.4405460357666016e-06
# iteration 415, reconstraction error: 0.16735699772834778, decrease = 2.473592758178711e-06
# iteration 416, reconstraction error: 0.167352557182312, decrease = 4.4405460357666016e-06
# iteration 417, reconstraction error: 0.16734959185123444, decrease = 2.9653310775756836e-06
# iteration 418, reconstraction error: 0.16734564304351807, decrease = 3.948807716369629e-06
# iteration 419, reconstraction error: 0.1673426777124405, decrease = 2.9653310775756836e-06
# iteration 420, reconstraction error: 0.16733872890472412, decrease = 3.948807716369629e-06
# iteration 421, reconstraction error: 0.16733527183532715, decrease = 3.4570693969726562e-06
# iteration 422, reconstraction error: 0.16733181476593018, decrease = 3.4570693969726562e-06
# iteration 423, reconstraction error: 0.16732735931873322, decrease = 4.455447196960449e-06
# iteration 424, reconstraction error: 0.16732490062713623, decrease = 2.4586915969848633e-06
# iteration 425, reconstraction error: 0.16732093691825867, decrease = 3.9637088775634766e-06
# iteration 426, reconstraction error: 0.16731798648834229, decrease = 2.950429916381836e-06
# iteration 427, reconstraction error: 0.1673145294189453, decrease = 3.4570693969726562e-06
# iteration 428, reconstraction error: 0.16731105744838715, decrease = 3.471970558166504e-06
# iteration 429, reconstraction error: 0.16730810701847076, decrease = 2.950429916381836e-06
# iteration 430, reconstraction error: 0.1673046350479126, decrease = 3.471970558166504e-06
# iteration 431, reconstraction error: 0.16730068624019623, decrease = 3.948807716369629e-06
# iteration 432, reconstraction error: 0.16729772090911865, decrease = 2.9653310775756836e-06
# iteration 433, reconstraction error: 0.16729377210140228, decrease = 3.948807716369629e-06
# iteration 434, reconstraction error: 0.1672912985086441, decrease = 2.473592758178711e-06
# iteration 435, reconstraction error: 0.16728685796260834, decrease = 4.4405460357666016e-06
# iteration 436, reconstraction error: 0.16728389263153076, decrease = 2.9653310775756836e-06
# iteration 437, reconstraction error: 0.1672799438238144, decrease = 3.948807716369629e-06
# iteration 438, reconstraction error: 0.1672774702310562, decrease = 2.473592758178711e-06
# iteration 439, reconstraction error: 0.16727352142333984, decrease = 3.948807716369629e-06
# iteration 440, reconstraction error: 0.16727004945278168, decrease = 3.471970558166504e-06
# iteration 441, reconstraction error: 0.1672661006450653, decrease = 3.948807716369629e-06
# iteration 442, reconstraction error: 0.16726362705230713, decrease = 2.473592758178711e-06
# iteration 443, reconstraction error: 0.16726066172122955, decrease = 2.9653310775756836e-06
# iteration 444, reconstraction error: 0.16725720465183258, decrease = 3.4570693969726562e-06
# iteration 445, reconstraction error: 0.1672537475824356, decrease = 3.4570693969726562e-06
# iteration 446, reconstraction error: 0.16724979877471924, decrease = 3.948807716369629e-06
# iteration 447, reconstraction error: 0.16724732518196106, decrease = 2.473592758178711e-06
# iteration 448, reconstraction error: 0.1672438681125641, decrease = 3.4570693969726562e-06
# iteration 449, reconstraction error: 0.1672409027814865, decrease = 2.9653310775756836e-06
# iteration 450, reconstraction error: 0.16723744571208954, decrease = 3.4570693969726562e-06
# iteration 451, reconstraction error: 0.16723397374153137, decrease = 3.471970558166504e-06
# iteration 452, reconstraction error: 0.1672305166721344, decrease = 3.4570693969726562e-06
# iteration 453, reconstraction error: 0.16722755134105682, decrease = 2.9653310775756836e-06
# iteration 454, reconstraction error: 0.16722507774829865, decrease = 2.473592758178711e-06
# iteration 455, reconstraction error: 0.16722112894058228, decrease = 3.948807716369629e-06
# iteration 456, reconstraction error: 0.1672176718711853, decrease = 3.4570693969726562e-06
# iteration 457, reconstraction error: 0.16721519827842712, decrease = 2.473592758178711e-06
# iteration 458, reconstraction error: 0.16721174120903015, decrease = 3.4570693969726562e-06
# iteration 459, reconstraction error: 0.1672077775001526, decrease = 3.9637088775634766e-06
# iteration 460, reconstraction error: 0.1672053188085556, decrease = 2.4586915969848633e-06
# iteration 461, reconstraction error: 0.16720284521579742, decrease = 2.473592758178711e-06
# iteration 462, reconstraction error: 0.16719838976860046, decrease = 4.455447196960449e-06
# iteration 463, reconstraction error: 0.16719591617584229, decrease = 2.473592758178711e-06
# iteration 464, reconstraction error: 0.1671924591064453, decrease = 3.4570693969726562e-06
# iteration 465, reconstraction error: 0.16718998551368713, decrease = 2.473592758178711e-06
# iteration 466, reconstraction error: 0.16718603670597076, decrease = 3.948807716369629e-06
# iteration 467, reconstraction error: 0.1671830713748932, decrease = 2.9653310775756836e-06
# iteration 468, reconstraction error: 0.167180597782135, decrease = 2.473592758178711e-06
# iteration 469, reconstraction error: 0.16717714071273804, decrease = 3.4570693969726562e-06
# iteration 470, reconstraction error: 0.16717417538166046, decrease = 2.9653310775756836e-06
# iteration 471, reconstraction error: 0.1671706885099411, decrease = 3.4868717193603516e-06
# iteration 472, reconstraction error: 0.16716772317886353, decrease = 2.9653310775756836e-06
# iteration 473, reconstraction error: 0.16716475784778595, decrease = 2.9653310775756836e-06
# iteration 474, reconstraction error: 0.16716179251670837, decrease = 2.9653310775756836e-06
# iteration 475, reconstraction error: 0.1671588271856308, decrease = 2.9653310775756836e-06
# iteration 476, reconstraction error: 0.16715537011623383, decrease = 3.4570693969726562e-06
# iteration 477, reconstraction error: 0.16715289652347565, decrease = 2.473592758178711e-06
# iteration 478, reconstraction error: 0.16714943945407867, decrease = 3.4570693969726562e-06
# iteration 479, reconstraction error: 0.1671469658613205, decrease = 2.473592758178711e-06
# iteration 480, reconstraction error: 0.16714350879192352, decrease = 3.4570693969726562e-06
# iteration 481, reconstraction error: 0.16714052855968475, decrease = 2.9802322387695312e-06
# iteration 482, reconstraction error: 0.16713707149028778, decrease = 3.4570693969726562e-06
# iteration 483, reconstraction error: 0.167135089635849, decrease = 1.9818544387817383e-06
# iteration 484, reconstraction error: 0.16713163256645203, decrease = 3.4570693969726562e-06
# iteration 485, reconstraction error: 0.16712866723537445, decrease = 2.9653310775756836e-06
# iteration 486, reconstraction error: 0.16712521016597748, decrease = 3.4570693969726562e-06
# iteration 487, reconstraction error: 0.1671222448348999, decrease = 2.9653310775756836e-06
# iteration 488, reconstraction error: 0.16711828112602234, decrease = 3.9637088775634766e-06
# iteration 489, reconstraction error: 0.16711629927158356, decrease = 1.9818544387817383e-06
# iteration 490, reconstraction error: 0.16711333394050598, decrease = 2.9653310775756836e-06
# iteration 491, reconstraction error: 0.1671103686094284, decrease = 2.9653310775756836e-06
# iteration 492, reconstraction error: 0.16710740327835083, decrease = 2.9653310775756836e-06
# iteration 493, reconstraction error: 0.16710443794727325, decrease = 2.9653310775756836e-06
# iteration 494, reconstraction error: 0.1671004742383957, decrease = 3.9637088775634766e-06
# iteration 495, reconstraction error: 0.1670989990234375, decrease = 1.475214958190918e-06
# iteration 496, reconstraction error: 0.16709554195404053, decrease = 3.4570693969726562e-06
# iteration 497, reconstraction error: 0.16709256172180176, decrease = 2.9802322387695312e-06
# iteration 498, reconstraction error: 0.16708959639072418, decrease = 2.9653310775756836e-06
# iteration 499, reconstraction error: 0.1670866310596466, decrease = 2.9653310775756836e-06
# iteration 500, reconstraction error: 0.16708366572856903, decrease = 2.9653310775756836e-06
# iteration 501, reconstraction error: 0.16708020865917206, decrease = 3.4570693969726562e-06
# iteration 502, reconstraction error: 0.16707772016525269, decrease = 2.4884939193725586e-06
# iteration 503, reconstraction error: 0.16707473993301392, decrease = 2.9802322387695312e-06
# iteration 504, reconstraction error: 0.16707177460193634, decrease = 2.9653310775756836e-06
# iteration 505, reconstraction error: 0.16707029938697815, decrease = 1.475214958190918e-06
# iteration 506, reconstraction error: 0.1670658439397812, decrease = 4.455447196960449e-06
# iteration 507, reconstraction error: 0.1670628786087036, decrease = 2.9653310775756836e-06
# iteration 508, reconstraction error: 0.16705991327762604, decrease = 2.9653310775756836e-06
# iteration 509, reconstraction error: 0.16705743968486786, decrease = 2.473592758178711e-06
# iteration 510, reconstraction error: 0.1670544594526291, decrease = 2.9802322387695312e-06
# iteration 511, reconstraction error: 0.1670519858598709, decrease = 2.473592758178711e-06
# iteration 512, reconstraction error: 0.16704803705215454, decrease = 3.948807716369629e-06
# iteration 513, reconstraction error: 0.16704605519771576, decrease = 1.9818544387817383e-06
# iteration 514, reconstraction error: 0.1670425981283188, decrease = 3.4570693969726562e-06
# iteration 515, reconstraction error: 0.1670401245355606, decrease = 2.473592758178711e-06
# iteration 516, reconstraction error: 0.16703765094280243, decrease = 2.473592758178711e-06
# iteration 517, reconstraction error: 0.16703468561172485, decrease = 2.9653310775756836e-06
# iteration 518, reconstraction error: 0.16703170537948608, decrease = 2.9802322387695312e-06
# iteration 519, reconstraction error: 0.1670287400484085, decrease = 2.9653310775756836e-06
# iteration 520, reconstraction error: 0.16702528297901154, decrease = 3.4570693969726562e-06
# iteration 521, reconstraction error: 0.16702330112457275, decrease = 1.9818544387817383e-06
# iteration 522, reconstraction error: 0.1670198142528534, decrease = 3.4868717193603516e-06
# iteration 523, reconstraction error: 0.16701684892177582, decrease = 2.9653310775756836e-06
# iteration 524, reconstraction error: 0.16701486706733704, decrease = 1.9818544387817383e-06
# iteration 525, reconstraction error: 0.16701190173625946, decrease = 2.9653310775756836e-06
# iteration 526, reconstraction error: 0.16700893640518188, decrease = 2.9653310775756836e-06
# iteration 527, reconstraction error: 0.1670059710741043, decrease = 2.9653310775756836e-06
# ...
# iteration 708, reconstraction error: 0.16652965545654297, decrease = 1.9818544387817383e-06
# iteration 709, reconstraction error: 0.1665266752243042, decrease = 2.9802322387695312e-06
# iteration 710, reconstraction error: 0.16652420163154602, decrease = 2.473592758178711e-06
# iteration 711, reconstraction error: 0.16652171313762665, decrease = 2.4884939193725586e-06
# iteration 712, reconstraction error: 0.16651973128318787, decrease = 1.9818544387817383e-06
# iteration 713, reconstraction error: 0.16651774942874908, decrease = 1.9818544387817383e-06
# iteration 714, reconstraction error: 0.16651476919651031, decrease = 2.9802322387695312e-06
# iteration 715, reconstraction error: 0.16651326417922974, decrease = 1.5050172805786133e-06
# iteration 716, reconstraction error: 0.16651029884815216, decrease = 2.9653310775756836e-06
# iteration 717, reconstraction error: 0.16650831699371338, decrease = 1.9818544387817383e-06
# iteration 718, reconstraction error: 0.166505828499794, decrease = 2.4884939193725586e-06
# iteration 719, reconstraction error: 0.16650284826755524, decrease = 2.9802322387695312e-06
# iteration 720, reconstraction error: 0.16649988293647766, decrease = 2.9653310775756836e-06
# iteration 721, reconstraction error: 0.16649888455867767, decrease = 9.98377799987793e-07
# iteration 722, reconstraction error: 0.1664969027042389, decrease = 1.9818544387817383e-06
# iteration 723, reconstraction error: 0.16649392247200012, decrease = 2.9802322387695312e-06
# iteration 724, reconstraction error: 0.16649192571640015, decrease = 1.996755599975586e-06
# iteration 725, reconstraction error: 0.16648894548416138, decrease = 2.9802322387695312e-06
# iteration 726, reconstraction error: 0.1664864718914032, decrease = 2.473592758178711e-06
# iteration 727, reconstraction error: 0.16648449003696442, decrease = 1.9818544387817383e-06
# iteration 728, reconstraction error: 0.16648200154304504, decrease = 2.4884939193725586e-06
# iteration 729, reconstraction error: 0.16647952795028687, decrease = 2.473592758178711e-06
# iteration 730, reconstraction error: 0.16647803783416748, decrease = 1.4901161193847656e-06
# iteration 731, reconstraction error: 0.1664750576019287, decrease = 2.9802322387695312e-06
# iteration 732, reconstraction error: 0.16647206246852875, decrease = 2.995133399963379e-06
# iteration 733, reconstraction error: 0.16647057235240936, decrease = 1.4901161193847656e-06
# iteration 734, reconstraction error: 0.16646859049797058, decrease = 1.9818544387817383e-06
# iteration 735, reconstraction error: 0.1664661169052124, decrease = 2.473592758178711e-06
# iteration 736, reconstraction error: 0.16646362841129303, decrease = 2.4884939193725586e-06
# iteration 737, reconstraction error: 0.16646115481853485, decrease = 2.473592758178711e-06
# iteration 738, reconstraction error: 0.16646015644073486, decrease = 9.98377799987793e-07
# iteration 739, reconstraction error: 0.1664571762084961, decrease = 2.9802322387695312e-06
# iteration 740, reconstraction error: 0.16645418107509613, decrease = 2.995133399963379e-06
# iteration 741, reconstraction error: 0.16645121574401855, decrease = 2.9653310775756836e-06
# iteration 742, reconstraction error: 0.16645021736621857, decrease = 9.98377799987793e-07
# iteration 743, reconstraction error: 0.1664472371339798, decrease = 2.9802322387695312e-06
# iteration 744, reconstraction error: 0.1664457470178604, decrease = 1.4901161193847656e-06
# iteration 745, reconstraction error: 0.16644278168678284, decrease = 2.9653310775756836e-06
# iteration 746, reconstraction error: 0.16644029319286346, decrease = 2.4884939193725586e-06
# iteration 747, reconstraction error: 0.16643781960010529, decrease = 2.473592758178711e-06
# iteration 748, reconstraction error: 0.1664363294839859, decrease = 1.4901161193847656e-06
# iteration 749, reconstraction error: 0.16643431782722473, decrease = 2.0116567611694336e-06
# iteration 750, reconstraction error: 0.16643184423446655, decrease = 2.473592758178711e-06
# iteration 751, reconstraction error: 0.16642886400222778, decrease = 2.9802322387695312e-06
# iteration 752, reconstraction error: 0.1664273738861084, decrease = 1.4901161193847656e-06
# iteration 753, reconstraction error: 0.16642539203166962, decrease = 1.9818544387817383e-06
# iteration 754, reconstraction error: 0.16642192006111145, decrease = 3.471970558166504e-06
# iteration 755, reconstraction error: 0.16642042994499207, decrease = 1.4901161193847656e-06
# iteration 756, reconstraction error: 0.16641844809055328, decrease = 1.9818544387817383e-06
# iteration 757, reconstraction error: 0.16641545295715332, decrease = 2.995133399963379e-06
# iteration 758, reconstraction error: 0.16641347110271454, decrease = 1.9818544387817383e-06
# iteration 759, reconstraction error: 0.16641247272491455, decrease = 9.98377799987793e-07
# iteration 760, reconstraction error: 0.16640949249267578, decrease = 2.9802322387695312e-06
# iteration 761, reconstraction error: 0.166407510638237, decrease = 1.9818544387817383e-06
# iteration 762, reconstraction error: 0.16640403866767883, decrease = 3.471970558166504e-06
# iteration 763, reconstraction error: 0.16640254855155945, decrease = 1.4901161193847656e-06
# iteration 764, reconstraction error: 0.16640056669712067, decrease = 1.9818544387817383e-06
# iteration 765, reconstraction error: 0.16639858484268188, decrease = 1.9818544387817383e-06
# iteration 766, reconstraction error: 0.16639657318592072, decrease = 2.0116567611694336e-06
# iteration 767, reconstraction error: 0.16639359295368195, decrease = 2.9802322387695312e-06
# iteration 768, reconstraction error: 0.16639161109924316, decrease = 1.9818544387817383e-06
# iteration 769, reconstraction error: 0.16638913750648499, decrease = 2.473592758178711e-06
# iteration 770, reconstraction error: 0.166388139128685, decrease = 9.98377799987793e-07
# iteration 771, reconstraction error: 0.16638466715812683, decrease = 3.471970558166504e-06
# iteration 772, reconstraction error: 0.16638317704200745, decrease = 1.4901161193847656e-06
# iteration 773, reconstraction error: 0.16638067364692688, decrease = 2.5033950805664062e-06
# iteration 774, reconstraction error: 0.1663786917924881, decrease = 1.9818544387817383e-06
# iteration 775, reconstraction error: 0.16637670993804932, decrease = 1.9818544387817383e-06
# iteration 776, reconstraction error: 0.16637422144412994, decrease = 2.4884939193725586e-06
# iteration 777, reconstraction error: 0.16637273132801056, decrease = 1.4901161193847656e-06
# iteration 778, reconstraction error: 0.16636976599693298, decrease = 2.9653310775756836e-06
# iteration 779, reconstraction error: 0.166367769241333, decrease = 1.996755599975586e-06
# iteration 780, reconstraction error: 0.16636529564857483, decrease = 2.473592758178711e-06
# iteration 781, reconstraction error: 0.16636380553245544, decrease = 1.4901161193847656e-06
# iteration 782, reconstraction error: 0.16636130213737488, decrease = 2.5033950805664062e-06
# iteration 783, reconstraction error: 0.1663593202829361, decrease = 1.9818544387817383e-06
# iteration 784, reconstraction error: 0.16635683178901672, decrease = 2.4884939193725586e-06
# iteration 785, reconstraction error: 0.16635484993457794, decrease = 1.9818544387817383e-06
# iteration 786, reconstraction error: 0.16635286808013916, decrease = 1.9818544387817383e-06
# iteration 787, reconstraction error: 0.1663498878479004, decrease = 2.9802322387695312e-06
# iteration 788, reconstraction error: 0.1663488894701004, decrease = 9.98377799987793e-07
# iteration 789, reconstraction error: 0.16634690761566162, decrease = 1.9818544387817383e-06
# iteration 790, reconstraction error: 0.16634391248226166, decrease = 2.995133399963379e-06
# iteration 791, reconstraction error: 0.16634291410446167, decrease = 9.98377799987793e-07
# iteration 792, reconstraction error: 0.1663399487733841, decrease = 2.9653310775756836e-06
# iteration 793, reconstraction error: 0.16633795201778412, decrease = 1.996755599975586e-06
# iteration 794, reconstraction error: 0.16633547842502594, decrease = 2.473592758178711e-06
# iteration 795, reconstraction error: 0.16633348166942596, decrease = 1.996755599975586e-06
# iteration 796, reconstraction error: 0.16633100807666779, decrease = 2.473592758178711e-06
# iteration 797, reconstraction error: 0.166329026222229, decrease = 1.9818544387817383e-06
# iteration 798, reconstraction error: 0.16632603108882904, decrease = 2.995133399963379e-06
# iteration 799, reconstraction error: 0.16632454097270966, decrease = 1.4901161193847656e-06
# iteration 800, reconstraction error: 0.16632305085659027, decrease = 1.4901161193847656e-06
# iteration 801, reconstraction error: 0.16632205247879028, decrease = 9.98377799987793e-07
# iteration 802, reconstraction error: 0.1663190722465515, decrease = 2.9802322387695312e-06
# iteration 803, reconstraction error: 0.16631709039211273, decrease = 1.9818544387817383e-06
# iteration 804, reconstraction error: 0.16631510853767395, decrease = 1.9818544387817383e-06
# iteration 805, reconstraction error: 0.16631260514259338, decrease = 2.5033950805664062e-06
# iteration 806, reconstraction error: 0.166310116648674, decrease = 2.4884939193725586e-06
# iteration 807, reconstraction error: 0.16630813479423523, decrease = 1.9818544387817383e-06
# iteration 808, reconstraction error: 0.16630615293979645, decrease = 1.9818544387817383e-06
# iteration 809, reconstraction error: 0.16630415618419647, decrease = 1.996755599975586e-06
# iteration 810, reconstraction error: 0.1663021743297577, decrease = 1.9818544387817383e-06
# iteration 811, reconstraction error: 0.1663001924753189, decrease = 1.9818544387817383e-06
# iteration 812, reconstraction error: 0.16629770398139954, decrease = 2.4884939193725586e-06
# iteration 813, reconstraction error: 0.16629619896411896, decrease = 1.5050172805786133e-06
# iteration 814, reconstraction error: 0.16629470884799957, decrease = 1.4901161193847656e-06
# iteration 815, reconstraction error: 0.1662922352552414, decrease = 2.473592758178711e-06
# iteration 816, reconstraction error: 0.16628974676132202, decrease = 2.4884939193725586e-06
# iteration 817, reconstraction error: 0.16628825664520264, decrease = 1.4901161193847656e-06
# iteration 818, reconstraction error: 0.16628627479076385, decrease = 1.9818544387817383e-06
# iteration 819, reconstraction error: 0.16628427803516388, decrease = 1.996755599975586e-06
# iteration 820, reconstraction error: 0.1662818044424057, decrease = 2.473592758178711e-06
# iteration 821, reconstraction error: 0.16628031432628632, decrease = 1.4901161193847656e-06
# iteration 822, reconstraction error: 0.16627781093120575, decrease = 2.5033950805664062e-06
# iteration 823, reconstraction error: 0.16627582907676697, decrease = 1.9818544387817383e-06
# iteration 824, reconstraction error: 0.1662733405828476, decrease = 2.4884939193725586e-06
# iteration 825, reconstraction error: 0.1662723571062088, decrease = 9.834766387939453e-07
# iteration 826, reconstraction error: 0.16626887023448944, decrease = 3.4868717193603516e-06
# iteration 827, reconstraction error: 0.16626738011837006, decrease = 1.4901161193847656e-06
# iteration 828, reconstraction error: 0.16626539826393127, decrease = 1.9818544387817383e-06
# iteration 829, reconstraction error: 0.1662638932466507, decrease = 1.5050172805786133e-06
# iteration 830, reconstraction error: 0.16626191139221191, decrease = 1.9818544387817383e-06
# iteration 831, reconstraction error: 0.16625991463661194, decrease = 1.996755599975586e-06
# iteration 832, reconstraction error: 0.16625842452049255, decrease = 1.4901161193847656e-06
# iteration 833, reconstraction error: 0.166254460811615, decrease = 3.9637088775634766e-06
# iteration 834, reconstraction error: 0.166253462433815, decrease = 9.98377799987793e-07
# iteration 835, reconstraction error: 0.16625197231769562, decrease = 1.4901161193847656e-06
# iteration 836, reconstraction error: 0.16624999046325684, decrease = 1.9818544387817383e-06
# iteration 837, reconstraction error: 0.16624797880649567, decrease = 2.0116567611694336e-06
# iteration 838, reconstraction error: 0.16624599695205688, decrease = 1.9818544387817383e-06
# iteration 839, reconstraction error: 0.1662440150976181, decrease = 1.9818544387817383e-06
# iteration 840, reconstraction error: 0.16624201834201813, decrease = 1.996755599975586e-06
# iteration 841, reconstraction error: 0.16623954474925995, decrease = 2.473592758178711e-06
# iteration 842, reconstraction error: 0.16623754799365997, decrease = 1.996755599975586e-06
# iteration 843, reconstraction error: 0.16623656451702118, decrease = 9.834766387939453e-07
# iteration 844, reconstraction error: 0.1662335842847824, decrease = 2.9802322387695312e-06
# iteration 845, reconstraction error: 0.16623257100582123, decrease = 1.0132789611816406e-06
# iteration 846, reconstraction error: 0.16622859239578247, decrease = 3.978610038757324e-06
# iteration 847, reconstraction error: 0.16622810065746307, decrease = 4.917383193969727e-07
# iteration 848, reconstraction error: 0.1662266105413437, decrease = 1.4901161193847656e-06
# iteration 849, reconstraction error: 0.1662246286869049, decrease = 1.9818544387817383e-06
# iteration 850, reconstraction error: 0.16622263193130493, decrease = 1.996755599975586e-06
# iteration 851, reconstraction error: 0.16622065007686615, decrease = 1.9818544387817383e-06
# iteration 852, reconstraction error: 0.16621965169906616, decrease = 9.98377799987793e-07
# iteration 853, reconstraction error: 0.1662166565656662, decrease = 2.995133399963379e-06
# iteration 854, reconstraction error: 0.16621467471122742, decrease = 1.9818544387817383e-06
# iteration 855, reconstraction error: 0.16621267795562744, decrease = 1.996755599975586e-06
# iteration 856, reconstraction error: 0.16621118783950806, decrease = 1.4901161193847656e-06
# iteration 857, reconstraction error: 0.16620871424674988, decrease = 2.473592758178711e-06
# iteration 858, reconstraction error: 0.1662067174911499, decrease = 1.996755599975586e-06
# iteration 859, reconstraction error: 0.16620473563671112, decrease = 1.9818544387817383e-06
# iteration 860, reconstraction error: 0.16620275378227234, decrease = 1.9818544387817383e-06
# iteration 861, reconstraction error: 0.16620074212551117, decrease = 2.0116567611694336e-06
# iteration 862, reconstraction error: 0.1661982536315918, decrease = 2.4884939193725586e-06
# iteration 863, reconstraction error: 0.166197270154953, decrease = 9.834766387939453e-07
# iteration 864, reconstraction error: 0.16619478166103363, decrease = 2.4884939193725586e-06
# iteration 865, reconstraction error: 0.16619378328323364, decrease = 9.98377799987793e-07
# iteration 866, reconstraction error: 0.16619180142879486, decrease = 1.9818544387817383e-06
# iteration 867, reconstraction error: 0.1661892980337143, decrease = 2.5033950805664062e-06
# iteration 868, reconstraction error: 0.1661878079175949, decrease = 1.4901161193847656e-06
# iteration 869, reconstraction error: 0.16618682444095612, decrease = 9.834766387939453e-07
# iteration 870, reconstraction error: 0.16618384420871735, decrease = 2.9802322387695312e-06
# iteration 871, reconstraction error: 0.16618284583091736, decrease = 9.98377799987793e-07
# iteration 872, reconstraction error: 0.16618035733699799, decrease = 2.4884939193725586e-06
# iteration 873, reconstraction error: 0.166179358959198, decrease = 9.98377799987793e-07
# iteration 874, reconstraction error: 0.16617637872695923, decrease = 2.9802322387695312e-06
# iteration 875, reconstraction error: 0.16617438197135925, decrease = 1.996755599975586e-06
# iteration 876, reconstraction error: 0.16617289185523987, decrease = 1.4901161193847656e-06
# iteration 877, reconstraction error: 0.1661709100008011, decrease = 1.9818544387817383e-06
# iteration 878, reconstraction error: 0.1661694049835205, decrease = 1.5050172805786133e-06
# iteration 879, reconstraction error: 0.16616791486740112, decrease = 1.4901161193847656e-06
# iteration 880, reconstraction error: 0.16616544127464294, decrease = 2.473592758178711e-06
# iteration 881, reconstraction error: 0.16616295278072357, decrease = 2.4884939193725586e-06
# iteration 882, reconstraction error: 0.16616295278072357, decrease = 0.0
# PARAFAC converged after 882 iterations

# %%
factors_temporal_nmf = np.array(factors_nmf.factors[1].to('cpu')).T

# %% [raw]
# factors_temporal_nmf = nmf.components_.T

# %% [raw]
# factors_neuron_nmf = factors.factors[0].cpu().numpy()
# factors_temporal_nmf = factors.factors[1].cpu().numpy()

# %% [raw]
# plt.figure()
# plt.plot(np.arange(factors_temporal_nmf.shape[0])/Fs,  factors_temporal_nmf + 7*np.arange(rank));

# %% [raw]
# plt.figure()
# plt.plot(factors_neuron_nmf);

# %% [markdown]
# # Run Regression
# Regress z-scored NMF temporal factors onto z-scored neural data itself

# %%
indices_to_use = np.arange(int(Fs*60*10),neural_data_toUse.shape[1])
## z-score NMF outputsneural_data_toUse 
factors_temporal_nmf_zscore = scipy.stats.zscore(factors_temporal_nmf[:,indices_to_use],axis=1)
# neural_data_toUse_zscore = welford_moving_2D.make_rollingZScore(np.array(neural_data_toUse.to('cpu')).T, win_roll=int(Fs*60*10)).T

# %% [raw]
# plt.figure()
# plt.plot(np.arange(factors_temporal_nmf_zscore.shape[1])/Fs,  factors_temporal_nmf_zscore.T + 10*np.arange(rank)[None,:]);

# %%
neural_data_toUse_zscore = welford_moving_2D.make_rollingZScore(np.array(neural_data_toUse.to('cpu')).T, win_roll=int(Fs*60*10)).T
neural_data_toUse_zscore = neural_data_toUse_zscore[:,indices_to_use]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 108000/108000 [00:16<00:00, 6472.17it/s]
# d:\rh_local\github\basic_neural_processing_modules\bnpm\welford_moving_2D.py:142: RuntimeWarning: invalid value encountered in sqrt
#   X_zscore_roll = (list_of_values - X_mean_rolling)/np.sqrt(X_var_rolling)
# d:\rh_local\github\basic_neural_processing_modules\bnpm\welford_moving_2D.py:142: RuntimeWarning: invalid value encountered in true_divide
#   X_zscore_roll = (list_of_values - X_mean_rolling)/np.sqrt(X_var_rolling)

# %%
neural_data_toUse_zscore = np.nan_to_num(neural_data_toUse_zscore, nan=0)

# %%
# %matplotlib notebook

plt.figure()
# plt.imshow(dFoF_sub_ptile[rmap.isort], aspect='auto', vmax=1)
plt.imshow(
    neural_data_toUse_zscore,
    aspect='auto',
    vmin=-1, 
    vmax=2,
)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
# OLS Regression
theta, factors_temporal_regression, bias = linear_regression.OLS(neural_data_toUse_zscore.T, factors_temporal_nmf_zscore.T)
factors_temporal_regression = factors_temporal_regression.T

# %%
# # Ridge Regression
# theta, factors_temporal_regression, bias = linear_regression.Ridge(neural_data_toUse_zscore.T, factors_temporal_nmf_zscore.T, lam=100000)
# factors_temporal_regression = factors_temporal_regression.T

# %%
# # ElasticNet Regression
# elr = sklearn.linear_model.ElasticNet(
#     alpha=0.1,
#     l1_ratio=0.05, 
#     fit_intercept=False,
# #     normalize='deprecated',
# #     precompute=False,
#     max_iter=1000, 
# #     copy_X=True, 
#     tol=0.0001,
# #     warm_start=False, 
#     positive=False,
#     random_state=42, 
#     selection='cyclic',
# #     verbose=True,
# )
# elr.fit(neural_data_toUse_zscore.T, factors_temporal_nmf_zscore.T)

# theta = elr.coef_.T
# factors_temporal_regression = elr.predict(neural_data_toUse_zscore.T).T

# %%
plt.figure()
plt.plot(np.arange(factors_temporal_nmf_zscore.shape[1])/Fs,  factors_temporal_nmf_zscore.T + 10*np.arange(rank)[None,:], alpha=0.3);
plt.gca().set_prop_cycle(None)
plt.plot(np.arange(factors_temporal_regression.shape[1])/Fs,  factors_temporal_regression.T + 10*np.arange(rank)[None,:]);
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
similarity.EV(factors_temporal_nmf_zscore.T, factors_temporal_regression.T)
# Out:
# (array([0.7305364 , 0.8072173 , 0.6124661 , 0.43889916, 0.4140488 ,
#         0.92520577, 0.8462325 , 0.58907574, 0.7303035 , 0.75897384],
#        dtype=float32),
#  0.68529594,
#  0.68529594)

# %%
# Filter based on Explained Variance
# If we can't predict a factor well, don't keep it
ev_threshold = 0.7
_, pairwise, evr_weighted, _ = similarity.pairwise_orthogonalization(factors_temporal_regression.T.astype(np.float32), factors_temporal_nmf_zscore.T.astype(np.float32))
factors_temporal_tokeep = factors_temporal_regression[pairwise > ev_threshold]

rank_good = (pairwise > ev_threshold).sum()
print(f'Rank above 0.7 EV: {rank_good}')
# Out:
# Rank above 0.7 EV: 6

# %%
pairwise
# Out:
# array([0.7309439 , 0.8073974 , 0.6144024 , 0.43896824, 0.41419554,
#        0.92562836, 0.8468605 , 0.58908105, 0.7303097 , 0.7591359 ],
#       dtype=float32)

# %%
_, _, evrs = get_highest_evr_var(neural_data_toUse[:,indices_to_use].cpu().numpy().T, factors_temporal_tokeep,  np.ones(rank_good, bool))
# _, _, evrs = get_highest_evr_var(neural_data_toUse[:,indices_to_use].T, factors_temporal_tokeep,  np.ones(rank, bool))

# %%
# %matplotlib notebook
plt.figure()
plt.plot(np.arange(factors_temporal_tokeep.shape[1])/Fs,  factors_temporal_nmf_zscore[np.argsort(evrs)[::-1],:].T + 10*np.arange(rank_good),alpha=0.4)
plt.gca().set_prop_cycle(None)
plt.plot(np.arange(factors_temporal_tokeep.shape[1])/Fs,  factors_temporal_tokeep[np.argsort(evrs)[::-1],:].T + 10*np.arange(rank_good));
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
weights = theta[:,np.argsort(evrs)[::-1]]
# weights = theta
sf_weights = np.einsum('ij,ikl->jkl', weights,sf[iscell])

# %matplotlib notebook
display_toggle_image_stack(
    sf_weights, 
    clim=[sf_weights.min(), sf_weights.max()]
)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# interactive(children=(IntSlider(value=0, description='i_frame', max=5), Output()), _dom_classes=('widget-inter…

# %% [markdown]
# # Run Orthogonalization

# %%
factors_orth = copy.deepcopy(factors_temporal_tokeep)
num_factors = rank_good
hits = np.ones(num_factors, bool)
for i in range(num_factors-1):
    ind_to_orthogonalize, factor_to_orthogonalize, evrs = get_highest_evr_var(neural_data_toUse_zscore.T, factors_orth, hits)
    print(f'Factor at {ind_to_orthogonalize} index explains {evrs[ind_to_orthogonalize]} of the variance in neural data')
    hits[ind_to_orthogonalize] = False
    factors_orth[hits] = np.transpose(orthogonalize_simple(factors_orth[hits].T, factor_to_orthogonalize))
# Out:
# Factor at 2 index explains 0.007464706897735596 of the variance in neural data
# Factor at 0 index explains 0.003937363624572754 of the variance in neural data
# Factor at 1 index explains 0.0035449862480163574 of the variance in neural data
# Factor at 5 index explains 0.0027707815170288086 of the variance in neural data
# Factor at 4 index explains 0.0026029348373413086 of the variance in neural data

# %%
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(np.corrcoef(factors_temporal_tokeep),vmin=-1)
ax2.imshow(np.corrcoef(factors_orth),vmin=-1)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
_, _, evrs = get_highest_evr_var(neural_data_toUse_zscore.T, factors_orth,  np.ones(num_factors, bool))

# %%
np.sort(evrs)
# Out:
# array([0.00251794, 0.00260293, 0.00277078, 0.00354499, 0.00393736,
#        0.00746471])

# %% [markdown]
# # Run Regression Pt 2

# %%
# OLS Regression
theta, factors_orth_regression, bias = linear_regression.OLS(neural_data_toUse_zscore.T, factors_orth.T)
factors_orth_regression = factors_orth_regression.T

# %%
_, _, evrs = get_highest_evr_var(neural_data_toUse[:,indices_to_use].cpu().numpy().T, factors_orth,  np.ones(num_factors, bool))

# %%
plt.figure()
plt.plot(np.sort(evrs)[::-1])
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %% [markdown]
# # Visualize

# %%
# %matplotlib notebook
plt.figure()
plt.plot(np.arange(factors_temporal_tokeep.shape[1])/Fs, factors_temporal_tokeep[np.argsort(evrs)[::-1],:].T + 10*np.arange(rank_good),alpha=0.4)
plt.gca().set_prop_cycle(None)
plt.plot(np.arange(factors_temporal_tokeep.shape[1])/Fs, factors_orth_regression[np.argsort(evrs)[::-1],:].T + 10*np.arange(rank_good))
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# [<matplotlib.lines.Line2D at 0x275cbeee310>,
#  <matplotlib.lines.Line2D at 0x275cbeee1c0>,
#  <matplotlib.lines.Line2D at 0x275cbeee4c0>,
#  <matplotlib.lines.Line2D at 0x275cbeeecd0>,
#  <matplotlib.lines.Line2D at 0x275cbef1190>,
#  <matplotlib.lines.Line2D at 0x275cbef1ee0>]

# %%
weights = theta[:,np.argsort(evrs)[::-1]]
sf_weights = np.einsum('ij,ikl->jkl', weights,sf[iscell])

factors_orth_regression_sorted = factors_orth_regression[np.argsort(evrs)[::-1]]

# %matplotlib notebook
display_toggle_image_stack(sf_weights)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# interactive(children=(IntSlider(value=0, description='i_frame', max=5), Output()), _dom_classes=('widget-inter…

# %%
weights_zeroSum = weights - weights.sum(x)

# %%
plt.figure()
plt.imshow(neural_data_toUse_zscore, aspect='auto', vmax=4)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
# %matplotlib notebook
plt.figure()
plt.imshow(theta[:,:],aspect='auto', interpolation='none')
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %% [markdown]
# # Save it all

# %%
factor_to_use = 0 # 0-indexed
weights = theta[:,np.argsort(evrs)[::-1]]

weights_day0 = {
    "weights": weights[:,factor_to_use],
    "weights_all" : weights,
    "iscell_custom": iscell,
    "factor_to_use": factor_to_use,
    "sf_weights": sf_weights,
#     "factors_temporal": factors_temporal_tokeep,
    "factors_temporal": factors_orth_regression_sorted,
}


F = scipy.io.savemat(path_save.with_suffix('.mat') , weights_day0)

np.save(path_save.with_suffix('.npy') , weights_day0)

# %% [markdown]
# # Load in old outputs

# %%
import numpy as np

# %%
data = np.load(r'D:/RH_local/data/BMI_cage_1511_4/mouse_1511L/20230111/analysis_data/weights_day0.npy', allow_pickle=True)[()]

# %%
data.keys()
# Out:
# dict_keys(['weights', 'weights_all', 'iscell_custom', 'factor_to_use', 'sf_weights', 'factors_temporal'])

# %%
import bnpm.plotting_helpers

# %%
# weights = theta[:,np.argsort(evrs)[::-1]]
# sf_weights = np.einsum('ij,ikl->jkl', data['weights_all'], sf[data['iscell_custom']])

# %matplotlib notebook
bnpm.plotting_helpers.display_toggle_image_stack(data['sf_weights'])
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# interactive(children=(IntSlider(value=0, description='i_frame', max=5), Output()), _dom_classes=('widget-inter…

# %%
components , scores , explained_variance_ratio_ , stds = decomposition.simple_pca(neural_data_toUse.T.cpu().numpy() , n_components=None , mean_sub=True, zscore=False, plot_pref=True , n_PCs_toPlot=2)

# %%
factors_orth_regression.shape

# %%
Fs = 30

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
fig, axs = plt.subplots(data['factors_temporal'].shape[0], 1, sharex=True)
for ii in range(axs.shape[0]):
#     axs[ii,0].plot(np.arange(data['factors_temporal'].shape[1])/Fs, factors_orth_regression[np.argsort(evrs)[-ii-1],:].T)
    axs[ii].plot(np.arange(data['factors_temporal'].shape[1])/Fs, data['factors_temporal'][ii])
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
# %matplotlib notebook
fig, axs = plt.subplots(data['factors_temporal'].shape[0], 1, sharex=True)
for ii in range(axs.shape[0]):
#     axs[ii,0].plot(np.arange(data['factors_temporal'].shape[1])/Fs, factors_orth_regression[np.argsort(evrs)[-ii-1],:].T)
    axs[ii].plot(np.arange(data['factors_temporal'].shape[1])/Fs, data['factors_temporal'][ii])
# Out:
# <img src="data:image/png;base64,..." width="812.2222437387637">

# %%
# %matplotlib notebook
plt.figure()
plt.plot(np.arange(factors_temporal_tokeep.shape[1])/Fs, factors_temporal_tokeep[np.argsort(evrs)[::-1],:].T + 10*np.arange(rank_good),alpha=0.4)
plt.gca().set_prop_cycle(None)
plt.plot(np.arange(factors_temporal_tokeep.shape[1])/Fs, factors_orth_regression[np.argsort(evrs)[::-1],:].T + 10*np.arange(rank_good))
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# [<matplotlib.lines.Line2D at 0x275cbeee310>,
#  <matplotlib.lines.Line2D at 0x275cbeee1c0>,
#  <matplotlib.lines.Line2D at 0x275cbeee4c0>,
#  <matplotlib.lines.Line2D at 0x275cbeeecd0>,
#  <matplotlib.lines.Line2D at 0x275cbef1190>,
#  <matplotlib.lines.Line2D at 0x275cbef1ee0>]

# %%
import rastermap

# %%
rmap = rastermap.Rastermap(
    n_components=1,
    n_X=40,
#     nPC=200,
#     init='pca',
#     alpha=1.0,
#     K=1.0,
#     mode='basic',
#     verbose=True,
#     annealing=True,
#     constraints=2,
)

# %%
# embedding = rmap.fit_transform(neural_data_toUse.cpu().numpy())
# embedding = rmap.fit_transform(dFoF)
embedding = rmap.fit_transform(np.concatenate([neural_data_toUse.cpu().numpy()[:,indices_to_use], factors_orth_regression]))

# %%
plt.figure()
plt.hist(embedding, 400);
plt.hist(embedding[-10:], 100);

# %%
plt.figure()
plt.imshow(
#     timeSeries.scale_between(neural_data_toUse.cpu().numpy()[rmap.isort], lower_percentile=10, upper_percentile=90), 
#     timeSeries.scale_between(spks_s2p[rmap.isort], lower_percentile=10, upper_percentile=90), 
#     dFoF[rmap.isort], vmax=5, 
    np.concatenate([neural_data_toUse.cpu().numpy()[:,indices_to_use], factors_orth_regression])[rmap.isort], 
    vmin=0,
    vmax=5, 
    aspect='auto',
#     extent=[0, indices_to_use.max()/Fs, 0, neural_data_toUse.shape[0]]
)
plt.xticks(ticks=np.arange(0,factors_temporal_tokeep.shape[1], 10000), labels=np.round(np.arange(0,factors_temporal_tokeep.shape[1], 10000)/Fs))

# %%
f, (ax1, ax2) = plt.subplots(2, 1,sharex=True)
ax1.imshow(
#     timeSeries.scale_between(neural_data_toUse.cpu().numpy()[rmap.isort], lower_percentile=10, upper_percentile=90), 
#     timeSeries.scale_between(spks_s2p[rmap.isort], lower_percentile=10, upper_percentile=90), 
#     dFoF[rmap.isort], vmax=5, 
    np.concatenate([neural_data_toUse.cpu().numpy()[:,indices_to_use], factors_orth_regression])[rmap.isort], 
    vmin=0,
    vmax=5, 
    aspect='auto',
#     extent=[0, indices_to_use.max()/Fs, 0, neural_data_toUse.shape[0]]
)
#ax1.set_xticks(ticks=np.arange(0,factors_temporal_tokeep.shape[1], 10000), labels=np.round(np.arange(0,factors_temporal_tokeep.shape[1], 10000)/Fs))
ax2.plot(factors_temporal_tokeep[np.argsort(evrs)[::-1],:].T + 10*np.arange(10),alpha=0.4)
ax2.plot(factors_orth_regression[np.argsort(evrs)[::-1],:].T + 10*np.arange(10))

# %%
indices_to_use.shape
