# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import copy

# %%
dir_github        = Path(r'D:\RH_local\github').resolve()

dir_day0 = Path(r'D:\RH_local\data\scanimage data\round 5 experiments\mouse 2_6\20210409').resolve()
dir_dayN = Path(r'D:\RH_local\data\scanimage data\round 5 experiments\mouse 2_6\20210410_test').resolve()



dir_day0_analysis = dir_day0 / 'analysis_lastNight'
dir_dayN_analysis = dir_dayN / 'analysis_lastNight'

path_weights_day0 = dir_day0_analysis / 'weights_day0.npy'

dir_s2p_0 = dir_day0 / 'exp' / 'suite2p' / 'plane0'
dir_s2p_N = dir_dayN / 'exp' / 'suite2p' / 'plane0'

path_spks_day0      = dir_day0_analysis / 'spks_cas.npy'
path_spks_dayN      = dir_dayN_analysis / 'spks_cas.npy'
path_spksCas_params_day0 = dir_day0_analysis / 'spksCas_params.pkl'
path_spksCas_params_dayN = dir_dayN_analysis / 'spksCas_params.pkl'
path_ucids     = dir_dayN_analysis / 'UCIDs_20220208.pkl'

pathSuffixToStat = "stat.npy"
pathSuffixToOps = "ops.npy"

path_stat_0 = dir_s2p_0 / pathSuffixToStat
path_ops_0 = dir_s2p_0 / pathSuffixToOps

path_stat_N = dir_s2p_N / pathSuffixToStat
path_ops_N = dir_s2p_N / pathSuffixToOps

# %%
import sys
sys.path.append(str(dir_github))

# %load_ext autoreload
# %autoreload 2

from basic_neural_processing_modules import *

# %%
dir_github = Path(r'D:\RH_local\github').resolve()

import sys
# sys.path.append("/n/data1/hms/neurobio/sabatini/rich/github_repos/")
# sys.path.append("/media/rich/Home_Linux_partition/github_repos/")
sys.path.append(str(dir_github))

# %load_ext autoreload
# %autoreload 2
from basic_neural_processing_modules import *

# %load_ext autoreload
# %autoreload 2
from Big_Ugly_ROI_Tracker.multiEps.multiEps_modules import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
weights = np.load(path_weights_day0,allow_pickle=True)
iscell = weights[()]['iscell_custom']

# %%
ucids = pickle_helpers.simple_load(path_ucids)
ucids_by_session = ucids["UCIDs_bySession"]
ucids_valid = [session[session>-1] for session in ucids_by_session]

# %%
alignment_indices = np.ones(ucids_by_session[0].shape[0])*np.nan
for i, ucid0 in enumerate(ucids_by_session[0]):
    if ucid0 > -1:
        alignment_indices[i] = np.where(ucids_by_session[1]==ucid0)[0]

# %%
ops_all = [np.load(path, allow_pickle=True)[()] for path in [path_ops_0, path_ops_N]]
frame_height = ops_all[0]['meanImg'].shape[0]
frame_width = ops_all[0]['meanImg'].shape[1]

sf_all = import_and_convert_to_CellReg_spatialFootprints([path_stat_0, path_stat_N], frame_height=frame_height, frame_width=frame_width, dtype=np.float32)

sf_N_aligned = indexing.index_with_nans(sf_all[1], alignment_indices)

# %%
# %matplotlib notebook

display_toggle_image_stack((sf_all[0][:10].sum(0),sf_N_aligned[:10].sum(0)))
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# interactive(children=(IntSlider(value=0, description='i_frame', max=1), Output()), _dom_classes=('widget-inter…

# %%
sf_N_iscell = sf_N_aligned[iscell]

# %%
np.save(dir_dayN_analysis / 'alignment_indices.npy', alignment_indices)

scipy.io.savemat(dir_dayN_analysis / 'spatial_footprints_aligned.mat', {'spatial_footprints': sf_N_iscell})
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Input In [18], in <module>
#       1 np.save(dir_dayN_analysis / 'alignment_indices.npy', alignment_indices)
# ----> 3 scipy.io.savemat(dir_dayN_analysis / 'spatial_footprints_aligned.mat', {'spatial_footprints': sf_N_iscell})
#
# File ~\.conda\envs\BMI_IDAP\lib\site-packages\scipy\io\matlab\mio.py:298, in savemat(file_name, mdict, appendmat, format, long_field_names, do_compression, oned_as)
#     296 else:
#     297     raise ValueError("Format should be '4' or '5'")
# --> 298 MW.put_variables(mdict)
#
# File ~\.conda\envs\BMI_IDAP\lib\site-packages\scipy\io\matlab\mio5.py:892, in MatFile5Writer.put_variables(self, mdict, write_header)
#     890     self.file_stream.write(out_str)
#     891 else:  # not compressing
# --> 892     self._matrix_writer.write_top(var, name.encode('latin1'), is_global)
#
# File ~\.conda\envs\BMI_IDAP\lib\site-packages\scipy\io\matlab\mio5.py:633, in VarWriter5.write_top(self, arr, name, is_global)
#     631 self._var_name = name
#     632 # write the header and data
# --> 633 self.write(arr)
#
# File ~\.conda\envs\BMI_IDAP\lib\site-packages\scipy\io\matlab\mio5.py:672, in VarWriter5.write(self, arr)
#     670     self.write_char(narr, codec)
#     671 else:
# --> 672     self.write_numeric(narr)
#     673 self.update_matrix_tag(mat_tag_pos)
#
# File ~\.conda\envs\BMI_IDAP\lib\site-packages\scipy\io\matlab\mio5.py:698, in VarWriter5.write_numeric(self, arr)
#     696     self.write_element(arr.imag)
#     697 else:
# --> 698     self.write_element(arr)
#
# File ~\.conda\envs\BMI_IDAP\lib\site-packages\scipy\io\matlab\mio5.py:539, in VarWriter5.write_element(self, arr, mdtype)
#     537     self.write_smalldata_element(arr, mdtype, byte_count)
#     538 else:
# --> 539     self.write_regular_element(arr, mdtype, byte_count)
#
# File ~\.conda\envs\BMI_IDAP\lib\site-packages\scipy\io\matlab\mio5.py:553, in VarWriter5.write_regular_element(self, arr, mdtype, byte_count)
#     551 tag = np.zeros((), NDT_TAG_FULL)
#     552 tag['mdtype'] = mdtype
# --> 553 tag['byte_count'] = byte_count
#     554 self.write_bytes(tag)
#     555 self.write_bytes(arr)
#
# OverflowError: Python int too large to convert to C long
